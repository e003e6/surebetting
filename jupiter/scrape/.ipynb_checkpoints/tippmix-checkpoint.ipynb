# %%
import json
import asyncio
from datetime import datetime
from playwright.async_api import async_playwright
from bs4 import BeautifulSoup
import pandas as pd
import dateparser
import re
import unicodedata

# %%
URL = "https://sports2.tippmixpro.hu/hu/esemenyek/11/labdarugas/anglia/premier-liga/manchester-city-leeds/286347330800881664/all"

# %%
df = pd.read_excel("../../Book1.xlsx")
kelllista = df[df['Unnamed: 0'] == 'tippmix'].values[0][1:].tolist()

# %%
def normalize_text(s):
    s = s.lower()
    s = unicodedata.normalize('NFD', s)
    s = ''.join(c for c in s if unicodedata.category(c) != 'Mn')
    s = s.replace(' ', '_')
    return s

# %%
def get_key(soup):
    hazai = normalize_text(soup.select_one('.MatchDetailsHeader__PartName--Home').get_text())
    venged = normalize_text(soup.select_one('.MatchDetailsHeader__PartName--Away').get_text())
    s = soup.select_one('.MatchTime__InfoPart').get_text()
    datum = dateparser.parse(s, languages=['hu']).strftime("%Y-%m-%d")
    return f'{hazai}-{venged}-{datum}'

# %%
def parse_html(html, kell=None):
    """
    Szinkron feldolgozás.
    Adatkinyerés
    """

    markets = {}

    soup = BeautifulSoup(html, "html.parser")

    container = soup.select_one(".MarketGroupsItem")

    if container is None:
        # nincs fő konténer -> üres eredmény
        return markets

    if kell: 
        kell.append('Gólszám - Rendes játékidő')


    for article in container.select("article"):
        
        soradatok = {}

        header_el = article.select_one(".Market__CollapseText")
        header_text = header_el.get_text(strip=True) if header_el else ""

        
        if kell: # ha van kell lista
            if header_text not in kell: # akkor ha nincsen benne a text akkor ki kell hagyni
                continue

        oddsgroup = article.select("ul.Market__OddsGroups")  # li elemek listája ezen az ul tag-en belül

        print(header_text)

        if len(oddsgroup) == 0:  
            print('bezárt menü')
            continue

        ligroup = oddsgroup[0].find_all('li', recursive=False)
        print('ligroup (sorok) száma:', len(ligroup))
    
        alcimCount = len(oddsgroup[0].find_all("li", class_="Market__OddsGroupTitle"))
        print('alcímek száma:', alcimCount)

        
        # ha nincsen alcím és nincsen header
        if len(ligroup) == 1 and alcimCount == 0: 
            print('1. osztály')

            if header_text == 'Gólszám - Rendes játékidő':
                header_text = header_text + ' - paros paratlan'
                print(header_text)
                            
            group = ligroup[0] # egy eleme van akkor a gorup legyen az egyetlen elem

            for alcim in group.find_all("li"):
                oszlop = [i.get_text(strip=True) for i in alcim.find_all('span')]
                if len(oszlop) < 2:
                    print('zárolt oszlop!')
                    continue
                soradatok[oszlop[0]] = oszlop[1]     # oszlop 0 itt lehet névcsere
                     
        # ha van alcím

        # a header száma egyezik a lingroup számmal
        elif alcimCount == len(ligroup):
            print('2. osztály')

            if header_text == 'Gólszám - Rendes játékidő':
                print()
                continue
                
            print('egyezik a lingroup és a header szám (kihagyás)!!!!')
            print()
            continue

        # egy header van (header van az első helyen)
        elif "Market__HeadersWrapper" in ligroup[0].get("class", []):
            header_titles = [i.get_text(strip=True) for i in ligroup[0].find_all('li')]
            #print('\t\t header:', header_titles)
            print('3. osztály')

            if header_text == 'Gólszám - Rendes játékidő':
                header_text = header_text + ' - tobb kevesebb'
                print(header_text)

            # ha van header akkor még el kell dönteni, hogy van-e Market__OddsGroupTitle
            if ligroup[1].select_one("li.Market__OddsGroupTitle"):
                
                for li in ligroup[1:]:
                    ossdd = [ods.get_text(strip=True) for ods in li.find_all('li')]
                    soradatok[ossdd[0]] = {header_titles[0]:ossdd[1], header_titles[2]:ossdd[2]}

            # nincsen header, csak sok alcím
            else:
                print('4. osztály')
                print('Nincsen header %%%%%')
                for sor in ligroup[1:]:
                    for i, oszlop in enumerate(sor.find_all('li')):
                        if len(oszlop.find_all('span')) != 2:
                            continue

                        text, odds = [m.get_text(strip=True) for m in oszlop.find_all('span')]
                        #print(header_titles[i], text, odds)
                        #print(text, odds)
                        soradatok[text] = odds
                        
        markets[header_text] = soradatok
        print(soradatok)
        print()
        
    return get_key(soup), markets

# %%
html = ''
# ------------- ASYNC LOOP -------------
async def run_scraper(url, headless=True, interval_sec=60, iterations=None, parser_fn=parse_html, on_result=None):
    """
    - Megnyitja a böngészőt és az oldalt.
    - Ciklusban (percenként) lekéri az oldal tartalmát.
    - A HTML-t átadja egy SZINKRON parser_fn-nek.
    - Ha adsz on_result callbacket (szinkron), annak átadja az eredményt.
    - iterations: ha None -> végtelen ciklus, ha szám -> ennyiszer fut.
    """
    global html
    
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=headless)
        context = await browser.new_context()
        page = await context.new_page()

        try:
            # első betöltés
            await page.goto(url, timeout=45000)
            await page.wait_for_selector(".MarketGroupsItem", timeout=15000)


            count = 0
            while True:
                try:
                    await page.reload(timeout=45000)
                    await page.wait_for_selector(".MarketGroupsItem", timeout=15000)
                    
                except Exception:
                    # ha reload nem ok, próbálkozhatsz goto-val
                    await page.goto(url, wait_until="domcontentloaded", timeout=45000)

                # HTML kiolvasása (ASYNC), majd átadjuk a SZINKRON parsernek
                html = await page.content()
                key, result = parser_fn(html)

                # ha adtál callbacket, itt megkapja az eredményt (SZINKRON)
                if on_result:
                    on_result(result)
                else:
                    # default: csak kiírjuk (váz)
                    print(result)

                count += 1
                if iterations is not None and count >= iterations:
                    break

                await asyncio.sleep(interval_sec)

        finally:
            await context.close()
            await browser.close()

# %%
await run_scraper(URL, headless=False, interval_sec=60, iterations=1)
# Out:
# 1X2 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,27', 'Döntetlen': '5,75', 'Leeds': '10,00'}
#
# Mindkét csapat szerez gólt - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Igen': '2,01', 'Nem': '1,73'}
#
# 1X2 + Mindkét csapat szerez gólt - Rendes játékidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'Hazai és Nem': '1,99', 'Hazai és Igen': '2,85', 'Döntetlen és Nem': '13,50', 'Döntetlen és Igen': '7,25', 'Vendég és Nem': '15,00', 'Vendég és Igen': '15,00'}
#
# Gólszám - Rendes játékidő
# ligroup (sorok) száma: 16
# alcímek száma: 15
# 3. osztály
# Gólszám - Rendes játékidő - tobb kevesebb
# {'0,5': {'Több, mint': '', 'Kevesebb, mint': '14,00'}, '1,5': {'Több, mint': '1,15', 'Kevesebb, mint': '4,75'}, '2': {'Több, mint': '1,23', 'Kevesebb, mint': '3,80'}, '2,25': {'Több, mint': '1,39', 'Kevesebb, mint': '2,80'}, '2,5': {'Több, mint': '1,54', 'Kevesebb, mint': '2,34'}, '2,75': {'Több, mint': '1,67', 'Kevesebb, mint': '2,10'}, '3': {'Több, mint': '1,86', 'Kevesebb, mint': '1,86'}, '3,25': {'Több, mint': '2,11', 'Kevesebb, mint': '1,66'}, '3,5': {'Több, mint': '2,36', 'Kevesebb, mint': '1,53'}, '3,75': {'Több, mint': '2,70', 'Kevesebb, mint': '1,41'}, '4': {'Több, mint': '3,40', 'Kevesebb, mint': '1,27'}, '4,25': {'Több, mint': '3,60', 'Kevesebb, mint': '1,25'}, '4,5': {'Több, mint': '4,05', 'Kevesebb, mint': '1,20'}, '5,5': {'Több, mint': '7,50', 'Kevesebb, mint': '1,06'}, '6,5': {'Több, mint': '14,00', 'Kevesebb, mint': ''}}
#
# Leeds gólszám - Rendes játékidő
# ligroup (sorok) száma: 5
# alcímek száma: 4
# 3. osztály
# {'0,5': {'Több, mint': '1,84', 'Kevesebb, mint': '1,88'}, '1,5': {'Több, mint': '5,00', 'Kevesebb, mint': '1,13'}, '2,5': {'Több, mint': '17,50', 'Kevesebb, mint': ''}, '3,5': {'Több, mint': '60,00', 'Kevesebb, mint': ''}}
#
# Manchester City gólszám - Rendes játékidő
# ligroup (sorok) száma: 7
# alcímek száma: 6
# 3. osztály
# {'0,5': {'Több, mint': '1,05', 'Kevesebb, mint': '8,25'}, '1,5': {'Több, mint': '1,38', 'Kevesebb, mint': '2,85'}, '2,5': {'Több, mint': '2,15', 'Kevesebb, mint': '1,64'}, '3,5': {'Több, mint': '3,95', 'Kevesebb, mint': '1,22'}, '4,5': {'Több, mint': '7,00', 'Kevesebb, mint': '1,07'}, '5,5': {'Több, mint': '16,50', 'Kevesebb, mint': ''}}
#
# Hendikep - Rendes játékidő
# ligroup (sorok) száma: 5
# alcímek száma: 5
# 2. osztály
# egyezik a lingroup és a header szám (kihagyás)!!!!
#
# Kétesély - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City vagy Döntetlen': '1,03', 'Manchester City vagy Leeds': '1,10', 'Leeds vagy Döntetlen': '3,30'}
#
# Döntetlennél a tét visszajár - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,07', 'Leeds': '7,25'}
#
# 1X2 + Gólszám 1,5 - Rendes játékidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'Hazai és Több, mint 1,5': '1,41', 'Hazai és Kevesebb, mint 1,5': '7,25', 'Döntetlen és Több, mint 1,5': '6,75', 'Döntetlen és Kevesebb, mint 1,5': '16,00', 'Vendég és Több, mint 1,5': '12,00', 'Vendég és Kevesebb, mint 1,5': '21,00'}
#
# 1X2 + Gólszám 2,5 - Rendes játékidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'Hazai és Több, mint 2,5': '1,81', 'Hazai és Kevesebb, mint 2,5': '3,70', 'Döntetlen és Több, mint 2,5': '18,50', 'Döntetlen és Kevesebb, mint 2,5': '6,75', 'Vendég és Több, mint 2,5': '15,00', 'Vendég és Kevesebb, mint 2,5': '16,50'}
#
# 1X2 + Gólszám 3,5 - Rendes játékidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'Hazai és Több, mint 3,5': '2,75', 'Hazai és Kevesebb, mint 3,5': '2,04', 'Döntetlen és Több, mint 3,5': '17,50', 'Döntetlen és Kevesebb, mint 3,5': '6,50', 'Vendég és Több, mint 3,5': '30,00', 'Vendég és Kevesebb, mint 3,5': '10,00'}
#
# 1X2 + Gólszám 4,5 - Rendes játékidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'Hazai és Több, mint 4,5': '4,65', 'Hazai és Kevesebb, mint 4,5': '1,58', 'Döntetlen és Több, mint 4,5': '60,00', 'Döntetlen és Kevesebb, mint 4,5': '5,25', 'Vendég és Több, mint 4,5': '40,00', 'Vendég és Kevesebb, mint 4,5': '9,50'}
#
# 1X2 + Gólszám 5,5 - Rendes játékidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'Hazai és Több, mint 5,5': '10,00', 'Hazai és Kevesebb, mint 5,5': '1,42', 'Döntetlen és Több, mint 5,5': '70,00', 'Döntetlen és Kevesebb, mint 5,5': '5,50', 'Vendég és Több, mint 5,5': '100,00', 'Vendég és Kevesebb, mint 5,5': '9,00'}
#
# Hazai csapat nyer vagy mindkét csapat szerez gólt - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Igen': '1,04', 'Nem': '6,25'}
#
# Döntetlen vagy mindkét csapat szerez gólt - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Igen': '1,79', 'Nem': '1,81'}
#
# Mindkét csapat szerez gólt vagy több, mint 2,5 gól lesz - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Igen': '1,36', 'Nem': '2,67'}
#
# Kaput eltaláló gólszerzési kísérletek száma - Rendes játékidő
# ligroup (sorok) száma: 5
# alcímek száma: 4
# 3. osztály
# {'7,5': {'Több, mint': '1,41', 'Kevesebb, mint': '2,50'}, '8,5': {'Több, mint': '1,74', 'Kevesebb, mint': '1,87'}, '9,5': {'Több, mint': '2,28', 'Kevesebb, mint': '1,49'}, '10,5': {'Több, mint': '3,05', 'Kevesebb, mint': '1,28'}}
#
# Félidő/végeredmény - Rendes játékidő
# ligroup (sorok) száma: 3
# alcímek száma: 0
# {}
#
# Pontos eredmény - Rendes játékidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'1:0': '7,25', '2:0': '6,25', '2:1': '8,25', '3:0': '7,25', '3:1': '9,75', '3:2': '22,00', '4:0': '11,50', '4:1': '15,50', '4:2': '30,00', '4:3': '90,00', '5:0': '20,00', '5:1': '25,00', '5:2': '60,00', '5:3': '125,00', '6:0': '40,00', '6:1': '50,00', '6:2': '90,00', '7:0': '80,00', '7:1': '90,00', '7:2': '150,00', '8:0': '100,00', '9:0': '125,00', '0:0': '14,50', '1:1': '9,75', '2:2': '20,00', '3:3': '70,00', '4:4': '150,00', '0:1': '22,00', '0:2': '50,00', '1:2': '25,00', '0:3': '125,00', '1:3': '70,00', '2:3': '60,00', '0:4': '175,00', '1:4': '125,00', '2:4': '125,00', '3:4': '125,00'}
#
# Szerez gólt? - Rendes játékidő
# ligroup (sorok) száma: 3
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'Erling Haaland': '1,51', 'Omar Marmoush': '2,35', 'Phil Foden': '2,75', 'Savinho': '2,75', 'Rayan Cherki': '3,30', 'Oscar Bobb': '3,40', 'Jeremy Doku': '3,90', 'Tijjani Reijnders': '3,90', 'Rodri Hernandez': '4,70', 'Bernardo Silva': '5,00', 'Nico González': '7,50', 'Rayan Ait-Nouri': '7,75', "Nico O'Reilly": '8,25', 'Matheus Luiz Nunes': '8,25', 'Josko Gvardiol': '8,75', 'Ruben Dias': '12,00', 'John Stones': '12,00', 'Rico Lewis': '12,50', 'Nathan Aké': '13,50', 'Abdukodir Khusanov': '14,50', 'Dominic Calvert-Lewin': '4,40', 'Lukas Nmecha': '6,00', 'Wilfried Gnonto': '6,75', 'Brenden Aaronson': '7,25', 'Daniel James': '7,25', 'Jack Harrison': '11,50', 'Pascal Struijk': '13,50', 'Anton Stach': '13,50', 'Sean Longstaff': '14,50', 'Jayden Bogle': '15,50', 'Ao Tanaka': '15,50', 'Ilia Gruev': '18,50', 'Ethan Ampadu': '20,00', 'James Justin': '20,00', 'Joe Rodon': '20,00', 'Jaka Bijol': '22,00', 'Gabriel Gudmundsson': '24,00'}
#
# Ázsiai hendikep - Rendes játékidő
# ligroup (sorok) száma: 23
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'-3,5': '5,25', '+3,5': '1,15', '-3': '4,65', '+3': '1,19', '-2,75': '3,50', '+2,75': '1,30', '-2,5': '2,85', '+2,5': '1,42', '-2,25': '2,57', '+2,25': '1,51', '-2': '60,00', '+2': '1,62', '-1,75': '30,00', '+1,75': '1,85', '-1,5': '23,00', '+1,5': '2,05', '-1,25': '22,00', '+1,25': '2,38', '-1': '22,00', '+1': '3,00', '-0,75': '11,50', '+0,75': '1,03', '-0,5': '8,25', '+0,5': '1,07', '-0,25': '7,50', '+0,25': '1,08', '0': '7,00'}
#
# 1X2 - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,62', 'Döntetlen': '2,67', 'Leeds': '8,25'}
#
# 1X2 - 2. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,51', 'Döntetlen': '3,15', 'Leeds': '7,25'}
#
# Gólszám - 1. félidő
# ligroup (sorok) száma: 11
# alcímek száma: 10
# 3. osztály
# {'0,5': {'Több, mint': '1,25', 'Kevesebb, mint': '3,65'}, '0,75': {'Több, mint': '1,33', 'Kevesebb, mint': '3,05'}, '1': {'Több, mint': '1,49', 'Kevesebb, mint': '2,48'}, '1,25': {'Több, mint': '1,88', 'Kevesebb, mint': '1,84'}, '1,5': {'Több, mint': '2,23', 'Kevesebb, mint': '1,60'}, '1,75': {'Több, mint': '2,75', 'Kevesebb, mint': '1,40'}, '2': {'Több, mint': '3,95', 'Kevesebb, mint': '1,21'}, '2,5': {'Több, mint': '4,95', 'Kevesebb, mint': '1,14'}, '3,5': {'Több, mint': '12,50', 'Kevesebb, mint': ''}, '4,5': {'Több, mint': '29,00', 'Kevesebb, mint': ''}}
#
# Gólszám - 2. félidő
# ligroup (sorok) száma: 5
# alcímek száma: 4
# 3. osztály
# {'0,5': {'Több, mint': '1,16', 'Kevesebb, mint': '4,70'}, '1,5': {'Több, mint': '1,81', 'Kevesebb, mint': '1,91'}, '2,5': {'Több, mint': '3,40', 'Kevesebb, mint': '1,28'}, '3,5': {'Több, mint': '7,25', 'Kevesebb, mint': '1,06'}}
#
# Ázsiai hendikep - 1. félidő
# ligroup (sorok) száma: 18
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'-2': '125,00', '+2': '1,04', '-1,75': '50,00', '+1,75': '1,15', '-1,5': '30,00', '+1,5': '1,28', '-1,25': '30,00', '+1,25': '1,32', '-1': '30,00', '+1': '1,48', '-0,75': '11,00', '+0,75': '1,01', '-0,5': '7,25', '+0,5': '1,06', '-0,25': '6,25', '+0,25': '1,09', '0': '5,00'}
#
# Mindkét csapat szerez gólt - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Igen': '4,70', 'Nem': '1,16'}
#
# Mindkét csapat szerez gólt - 2. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Igen': '3,60', 'Nem': '1,25'}
#
# Mindkét csapat szerez gólt + Gólszám - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Igen és Több, mint 2,5': '2,32', 'Nem és Kevesebb, mint 2,5': '2,65', 'Nem és Több, mint 2,5': '3,70', 'Igen és Kevesebb, mint 2,5': '9,75'}
#
# Mindkét csapat szerez gólt + Gólszám - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Nem és Kevesebb, mint 3,5': '2,06', 'Igen és Több, mint 3,5': '3,20', 'Igen és Kevesebb, mint 3,5': '4,40', 'Nem és Több, mint 3,5': '6,25'}
#
# Mindkét csapat szerez gólt + Gólszám - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Nem és Kevesebb, mint 4,5': '1,81', 'Igen és Kevesebb, mint 4,5': '2,90', 'Igen és Több, mint 4,5': '5,00', 'Nem és Több, mint 4,5': '12,00'}
#
# Mindkét csapat szerez gólt + Gólszám - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Nem és Kevesebb, mint 5,5': '1,72', 'Igen és Kevesebb, mint 5,5': '2,35', 'Igen és Több, mint 5,5': '8,75', 'Nem és Több, mint 5,5': '22,00'}
#
# Mindkét csapat szerez gólt + Gólszám - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Nem és Kevesebb, mint 3,5': '1,17', 'Igen és Kevesebb, mint 3,5': '6,00', 'Igen és Több, mint 3,5': '22,00', 'Nem és Több, mint 3,5': '40,00'}
#
# Mindkét csapat szerez gólt + Gólszám - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Nem és Kevesebb, mint 2,5': '1,25', 'Igen és Több, mint 2,5': '9,00', 'Igen és Kevesebb, mint 2,5': '9,75', 'Nem és Több, mint 2,5': '11,50'}
#
# Kétesély + Mindkét csapat szerez gólt - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City vagy Leeds és Nem': '1,87', 'Manchester City vagy Döntelen és Nem': '1,88', 'Manchester City vagy Döntetlen és Igen': '2,24', 'Manchester City vagy Leeds és Igen': '2,66', 'Leeds vagy Döntetlen és Igen': '5,25', 'Leeds vagy Döntelen és Nem': '9,00'}
#
# Kétesély + Mindkét csapat szerez gólt - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City vagy Döntelen és Nem': '1,29', 'Manchester City vagy Leeds és Nem': '1,62', 'Leeds vagy Döntelen és Nem': '2,70', 'Manchester City vagy Döntetlen és Igen': '5,25', 'Leeds vagy Döntetlen és Igen': '7,75', 'Manchester City vagy Leeds és Igen': '9,75'}
#
# 1X2 + Mindkét csapat szerez gólt - 2. félidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'Hazai és Igen': '7,00', 'Hazai és Nem': '1,80', 'Döntetlen és Nem': '4,70', 'Döntetlen és Igen': '6,50', 'Vendég és Igen': '25,00', 'Vendég és Nem': '8,00'}
#
# Mindkét félidőben lesz gól - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Igen': '1,51', 'Nem': '2,35'}
#
# 1. gól „X” perc előtt lesz? - Rendes játékidő
# ligroup (sorok) száma: 9
# alcímek száma: 8
# 3. osztály
# {'10': {'Igen': '3,50', 'Nem': '1,21'}, '20': {'Igen': '2,05', 'Nem': '1,60'}, '30': {'Igen': '1,56', 'Nem': '2,12'}, '40': {'Igen': '1,33', 'Nem': '2,75'}, '50': {'Igen': '1,17', 'Nem': '3,90'}, '60': {'Igen': '1,08', 'Nem': '5,25'}, '70': {'Igen': '1,03', 'Nem': '7,00'}, '80': {'Igen': '', 'Nem': '9,50'}}
#
# Leeds „X” perc előtt szerzi a(z) 1. gólját - Rendes játékidő
# ligroup (sorok) száma: 9
# alcímek száma: 8
# 3. osztály
# {'10': {'Igen': '11,00', 'Nem': ''}, '20': {'Igen': '6,25', 'Nem': '1,04'}, '30': {'Igen': '4,60', 'Nem': '1,12'}, '40': {'Igen': '3,65', 'Nem': '1,19'}, '50': {'Igen': '2,90', 'Nem': '1,30'}, '60': {'Igen': '2,51', 'Nem': '1,40'}, '70': {'Igen': '2,22', 'Nem': '1,51'}, '80': {'Igen': '2,01', 'Nem': '1,63'}}
#
# Manchester City „X” perc előtt szerzi a(z) 1. gólját - Rendes játékidő
# ligroup (sorok) száma: 9
# alcímek száma: 8
# 3. osztály
# {'10': {'Igen': '4,35', 'Nem': '1,13'}, '20': {'Igen': '2,46', 'Nem': '1,42'}, '30': {'Igen': '1,83', 'Nem': '1,77'}, '40': {'Igen': '1,53', 'Nem': '2,19'}, '50': {'Igen': '1,31', 'Nem': '2,85'}, '60': {'Igen': '1,20', 'Nem': '3,60'}, '70': {'Igen': '1,12', 'Nem': '4,60'}, '80': {'Igen': '1,07', 'Nem': '5,75'}}
#
# Melyik csapat szerzi a(z) 1. gólt? - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,25', 'Nincs': '15,00', 'Leeds': '4,10'}
#
# Melyik csapat szerzi a(z) 1. gólt? - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,57', 'Nincs': '3,45', 'Leeds': '5,00'}
#
# Melyik csapat szerzi a(z) 1. gólt? - 2. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,45', 'Nincs': '4,70', 'Leeds': '4,60'}
#
# Melyik félidőben lesz több gól? - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'1. félidő': '2,85', '2. félidő': '1,99', 'Döntetlen': '3,65'}
#
# Gólszám - Rendes játékidő
# ligroup (sorok) száma: 3
# alcímek száma: 3
# 2. osztály
#
# Gólszám - 1. félidő
# ligroup (sorok) száma: 3
# alcímek száma: 3
# 2. osztály
# egyezik a lingroup és a header szám (kihagyás)!!!!
#
# Gólszám - 2. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 1
# 2. osztály
# egyezik a lingroup és a header szám (kihagyás)!!!!
#
# Vendégcsapat győzelménél a tét visszajár - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Döntetlen': '4,80', 'Manchester City': '1,11'}
#
# Vendégcsapat győzelménél a tét visszajár - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Döntetlen': '2,33', 'Manchester City': '1,47'}
#
# Nem kap gólt - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,83', 'Leeds': '8,25'}
#
# Nem kap gólt - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,29', 'Leeds': '2,66'}
#
# Hátrányból nyer - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '8,00', 'Leeds': '30,00'}
#
# Pontos eredmény - 1. félidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'1:0': '3,15', '2:0': '5,25', '2:1': '14,50', '3:0': '12,50', '3:1': '30,00', '3:2': '90,00', '4:0': '35,00', '4:1': '60,00', '5:0': '90,00', '0:0': '3,40', '1:1': '9,00', '2:2': '60,00', '3:3': '200,00', '0:1': '9,75', '0:2': '50,00', '1:2': '45,00', '0:3': '125,00', '1:3': '125,00', '2:3': '150,00'}
#
# Pontos eredmény - 2. félidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'1:0': '3,65', '2:0': '5,00', '2:1': '11,50', '3:0': '10,00', '3:1': '22,00', '3:2': '60,00', '4:0': '22,00', '4:1': '45,00', '0:0': '4,75', '1:1': '8,25', '2:2': '40,00', '0:1': '10,50', '0:2': '40,00', '1:2': '30,00', '0:3': '100,00', '1:3': '90,00', '2:3': '100,00'}
#
# Kétesély - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City vagy Döntetlen': '1,03', 'Manchester City vagy Leeds': '1,35', 'Leeds vagy Döntetlen': '1,96'}
#
# Kétesély - 2. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City vagy Döntetlen': '1,03', 'Manchester City vagy Leeds': '1,25', 'Leeds vagy Döntetlen': '2,23'}
#
# Kétesély + Gólszám 1,5 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City vagy Döntetlen és Több, mint 1,5': '1,26', 'Manchester City vagy Leeds és Több, mint 1,5': '1,35', 'Leeds vagy Döntetlen és Több, mint 1,5': '4,90', 'Manchester City vagy Döntetlen és Kevesebb, mint 1,5': '5,50', 'Manchester City vagy Leeds és Kevesebb, mint 1,5': '6,00', 'Leeds vagy Döntetlen és Kevesebb, mint 1,5': '10,50'}
#
# Kétesély + Gólszám 2,5 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City vagy Leeds és Több, mint 2,5': '1,67', 'Manchester City vagy Döntetlen és Több, mint 2,5': '1,70', 'Manchester City vagy Döntetlen és Kevesebb, mint 2,5': '2,56', 'Manchester City vagy Leeds és Kevesebb, mint 2,5': '3,20', 'Leeds vagy Döntetlen és Kevesebb, mint 2,5': '5,25', 'Leeds vagy Döntetlen és Több, mint 2,5': '9,00'}
#
# Kétesély + Gólszám 3,5 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City vagy Döntetlen és Kevesebb, mint 3,5': '1,69', 'Manchester City vagy Leeds és Kevesebb, mint 3,5': '1,84', 'Manchester City vagy Döntetlen és Több, mint 3,5': '2,59', 'Manchester City vagy Leeds és Több, mint 3,5': '2,70', 'Leeds vagy Döntetlen és Kevesebb, mint 3,5': '4,50', 'Leeds vagy Döntetlen és Több, mint 3,5': '13,00'}
#
# Kétesély + Gólszám 4,5 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City vagy Döntetlen és Kevesebb, mint 4,5': '1,32', 'Manchester City vagy Leeds és Kevesebb, mint 4,5': '1,45', 'Leeds vagy Döntetlen és Kevesebb, mint 4,5': '3,80', 'Manchester City vagy Leeds és Több, mint 4,5': '4,55', 'Manchester City vagy Döntetlen és Több, mint 4,5': '4,70', 'Leeds vagy Döntetlen és Több, mint 4,5': '30,00'}
#
# Kétesély + Gólszám 1,5 - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City vagy Döntetlen és Kevesebb, mint 1,5': '1,80', 'Manchester City vagy Döntetlen és Több, mint 1,5': '2,45', 'Manchester City vagy Leeds és Kevesebb, mint 1,5': '2,62', 'Leeds vagy Döntetlen és Kevesebb, mint 1,5': '2,80', 'Manchester City vagy Leeds és Több, mint 1,5': '2,90', 'Leeds vagy Döntetlen és Több, mint 1,5': '7,00'}
#
# Kétesély + Gólszám 2,5 - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City vagy Döntetlen és Kevesebb, mint 2,5': '1,26', 'Manchester City vagy Leeds és Kevesebb, mint 2,5': '1,83', 'Leeds vagy Döntetlen és Kevesebb, mint 2,5': '2,20', 'Manchester City vagy Leeds és Több, mint 2,5': '5,50', 'Manchester City vagy Döntetlen és Több, mint 2,5': '6,00', 'Leeds vagy Döntetlen és Több, mint 2,5': '28,00'}
#
# Kétesély + Gólszám 3,5 - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City vagy Döntetlen és Kevesebb, mint 3,5': '1,12', 'Manchester City vagy Leeds és Kevesebb, mint 3,5': '1,51', 'Leeds vagy Döntetlen és Kevesebb, mint 3,5': '2,13', 'Manchester City vagy Döntetlen és Több, mint 3,5': '16,50', 'Manchester City vagy Leeds és Több, mint 3,5': '18,50', 'Leeds vagy Döntetlen és Több, mint 3,5': '50,00'}
#
# Kétesély + Gólszám 4,5 - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City vagy Döntetlen és Kevesebb, mint 4,5': '1,08', 'Manchester City vagy Leeds és Kevesebb, mint 4,5': '1,44', 'Leeds vagy Döntetlen és Kevesebb, mint 4,5': '2,09', 'Manchester City vagy Leeds és Több, mint 4,5': '60,00', 'Manchester City vagy Döntetlen és Több, mint 4,5': '60,00', 'Leeds vagy Döntetlen és Több, mint 4,5': '200,00'}
#
# Döntetlennél a tét visszajár - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,09', 'Leeds': '5,00'}
#
# Döntetlennél a tét visszajár - 2. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,09', 'Leeds': '5,00'}
#
# Félidő eredménye vagy végeredmény - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,19', 'Döntetlen': '2,23', 'Leeds': '5,25'}
#
# Félidő/végeredmény + Gólszám 1,5 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City / Manchester City és Több, mint 1,5': '2,02', 'Döntetlen / Manchester City és Több, mint 1,5': '6,00', 'Döntetlen / Manchester City és Kevesebb, mint 1,5': '13,50', 'Döntetlen / Döntetlen és Több, mint 1,5': '14,50', 'Manchester City / Manchester City és Kevesebb, mint 1,5': '16,00', 'Döntetlen / Döntetlen és Kevesebb, mint 1,5': '17,00', 'Leeds / Leeds és Több, mint 1,5': '21,00', 'Manchester City / Döntetlen és Több, mint 1,5': '22,00', 'Leeds / Döntetlen és Több, mint 1,5': '24,00', 'Leeds / Manchester City és Több, mint 1,5': '25,00', 'Döntetlen / Leeds és Több, mint 1,5': '30,00', 'Döntetlen / Leeds és Kevesebb, mint 1,5': '35,00', 'Leeds / Leeds és Kevesebb, mint 1,5': '40,00', 'Manchester City / Leeds és Több, mint 1,5': '70,00'}
#
# Félidő/végeredmény + Gólszám 2,5 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City / Manchester City és Több, mint 2,5': '2,48', 'Manchester City / Manchester City és Kevesebb, mint 2,5': '6,25', 'Döntetlen / Manchester City és Több, mint 2,5': '8,00', 'Döntetlen / Manchester City és Kevesebb, mint 2,5': '8,50', 'Döntetlen / Döntetlen és Kevesebb, mint 2,5': '10,00', 'Leeds / Manchester City és Több, mint 2,5': '25,00', 'Leeds / Leeds és Több, mint 2,5': '27,00', 'Döntetlen / Leeds és Kevesebb, mint 2,5': '30,00', 'Manchester City / Döntetlen és Kevesebb, mint 2,5': '30,00', 'Leeds / Leeds és Kevesebb, mint 2,5': '30,00', 'Leeds / Döntetlen és Kevesebb, mint 2,5': '35,00', 'Döntetlen / Leeds és Több, mint 2,5': '35,00', 'Döntetlen / Döntetlen és Több, mint 2,5': '40,00', 'Manchester City / Döntetlen és Több, mint 2,5': '45,00', 'Leeds / Döntetlen és Több, mint 2,5': '50,00', 'Manchester City / Leeds és Több, mint 2,5': '70,00'}
#
# Félidő/végeredmény + Gólszám 3,5 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City / Manchester City és Kevesebb, mint 3,5': '3,40', 'Manchester City / Manchester City és Több, mint 3,5': '3,70', 'Döntetlen / Manchester City és Kevesebb, mint 3,5': '5,75', 'Döntetlen / Döntetlen és Kevesebb, mint 3,5': '10,00', 'Döntetlen / Manchester City és Több, mint 3,5': '15,00', 'Leeds / Leeds és Kevesebb, mint 3,5': '20,00', 'Döntetlen / Leeds és Kevesebb, mint 3,5': '22,00', 'Manchester City / Döntetlen és Kevesebb, mint 3,5': '30,00', 'Leeds / Döntetlen és Kevesebb, mint 3,5': '35,00', 'Döntetlen / Döntetlen és Több, mint 3,5': '40,00', 'Leeds / Manchester City és Több, mint 3,5': '40,00', 'Manchester City / Döntetlen és Több, mint 3,5': '45,00', 'Leeds / Döntetlen és Több, mint 3,5': '50,00', 'Leeds / Manchester City és Kevesebb, mint 3,5': '50,00', 'Leeds / Leeds és Több, mint 3,5': '50,00', 'Döntetlen / Leeds és Több, mint 3,5': '80,00', 'Manchester City / Leeds és Kevesebb, mint 3,5': '100,00', 'Manchester City / Leeds és Több, mint 3,5': '125,00'}
#
# Hendikep - 1. félidő
# ligroup (sorok) száma: 3
# alcímek száma: 3
# 2. osztály
# egyezik a lingroup és a header szám (kihagyás)!!!!
#
# Hazai csapat győzelménél a tét visszajár - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Leeds': '2,53', 'Döntetlen': '1,40'}
#
# Hazai csapat győzelménél a tét visszajár - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Leeds': '3,50', 'Döntetlen': '1,21'}
#
# Melyik csapat szerzi az utolsó gólt? - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,24', 'Nincs': '17,50', 'Leeds': '3,95'}
#
# 1X2 + Gólszám 1,5 - 1. félidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'Hazai és Több, mint 1,5': '2,95', 'Hazai és Kevesebb, mint 1,5': '3,10', 'Döntetlen és Több, mint 1,5': '8,50', 'Döntetlen és Kevesebb, mint 1,5': '3,40', 'Vendég és Több, mint 1,5': '23,00', 'Vendég és Kevesebb, mint 1,5': '9,75'}
#
# 1X2 + Gólszám 2,5 - 1. félidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'Hazai és Több, mint 2,5': '6,00', 'Hazai és Kevesebb, mint 2,5': '2,09', 'Döntetlen és Több, mint 2,5': '60,00', 'Döntetlen és Kevesebb, mint 2,5': '2,64', 'Vendég és Több, mint 2,5': '35,00', 'Vendég és Kevesebb, mint 2,5': '8,75'}
#
# 1X2 + Gólszám 3,5 - 1. félidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'Hazai és Több, mint 3,5': '19,50', 'Hazai és Kevesebb, mint 3,5': '1,80', 'Döntetlen és Több, mint 3,5': '70,00', 'Döntetlen és Kevesebb, mint 3,5': '2,75', 'Vendég és Több, mint 3,5': '125,00', 'Vendég és Kevesebb, mint 3,5': '8,00'}
#
# Gólszám - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# Gólszám - Rendes játékidő - paros paratlan
# {'Páratlan': '1,86', 'Páros': '1,85'}
#
# Gólszám - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Páratlan': '1,97', 'Páros': '1,75'}
#
# Gólszám - 2. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Páratlan': '1,93', 'Páros': '1,78'}
#
# Leeds kapott gól nélkül játssza le - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Leeds: Igen': '8,00', 'Leeds: Nem': '1,01'}
#
# Manchester City kapott gól nélkül játssza le - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City: Igen': '1,82', 'Manchester City: Nem': '1,78'}
#
# Leeds kapott gól nélkül játssza le - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Leeds: Igen': '2,58', 'Leeds: Nem': '1,38'}
#
# Manchester City kapott gól nélkül játssza le - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City: Igen': '1,25', 'Manchester City: Nem': '3,20'}
#
# Leeds gólszám - 1. félidő
# ligroup (sorok) száma: 4
# alcímek száma: 3
# 3. osztály
# {'0,5': {'Több, mint': '3,30', 'Kevesebb, mint': '1,29'}, '1,5': {'Több, mint': '16,50', 'Kevesebb, mint': ''}, '2,5': {'Több, mint': '80,00', 'Kevesebb, mint': ''}}
#
# Manchester City gólszám - 1. félidő
# ligroup (sorok) száma: 4
# alcímek száma: 3
# 3. osztály
# {'0,5': {'Több, mint': '1,43', 'Kevesebb, mint': '2,66'}, '1,5': {'Több, mint': '3,00', 'Kevesebb, mint': '1,33'}, '2,5': {'Több, mint': '8,25', 'Kevesebb, mint': '1,05'}}
#
# Leeds gólszám - 2. félidő
# ligroup (sorok) száma: 4
# alcímek száma: 3
# 3. osztály
# {'0,5': {'Több, mint': '2,80', 'Kevesebb, mint': '1,38'}, '1,5': {'Több, mint': '10,50', 'Kevesebb, mint': '1,02'}, '2,5': {'Több, mint': '35,00', 'Kevesebb, mint': ''}}
#
# Manchester City gólszám - 2. félidő
# ligroup (sorok) száma: 4
# alcímek száma: 3
# 3. osztály
# {'0,5': {'Több, mint': '1,28', 'Kevesebb, mint': '3,40'}, '1,5': {'Több, mint': '2,30', 'Kevesebb, mint': '1,55'}, '2,5': {'Több, mint': '5,00', 'Kevesebb, mint': '1,13'}}
#
# Leeds szerez gólt? - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Leeds: Igen': '1,78', 'Leeds: Nem': '1,82'}
#
# Manchester City szerez gólt? - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City: Igen': '1,01', 'Manchester City: Nem': '8,00'}
#
# Leeds szerez gólt? - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Leeds: Igen': '3,20', 'Leeds: Nem': '1,25'}
#
# Manchester City szerez gólt? - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City: Igen': '1,38', 'Manchester City: Nem': '2,58'}
#
# Leeds szerez gólt? - 2. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Leeds: Igen': '2,70', 'Leeds: Nem': '1,34'}
#
# Manchester City szerez gólt? - 2. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City: Igen': '1,25', 'Manchester City: Nem': '3,20'}
#
# Leeds mindkét félidőben szerez gólt? - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Leeds: Igen': '8,25', 'Leeds: Nem': '1,01'}
#
# Manchester City mindkét félidőben szerez gólt? - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City: Igen': '1,82', 'Manchester City: Nem': '1,79'}
#
# Manchester City nyer legalább egy félidőt - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City: Igen': '1,11', 'Manchester City: Nem': '4,70'}
#
# Leeds nyer legalább egy félidőt - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Leeds: Igen': '4,00', 'Leeds: Nem': '1,16'}
#
# Leeds 0-ra nyeri - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# zárolt oszlop!
# {'Leeds: Igen': '14,00'}
#
# Manchester City 0-ra nyeri - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City: Igen': '1,99', 'Manchester City: Nem': '1,71'}
#
# Leeds 0-ra nyeri - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Leeds: Igen': '8,25', 'Leeds: Nem': '1,03'}
#
# Manchester City 0-ra nyeri - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City: Igen': '1,88', 'Manchester City: Nem': '1,80'}
#
# Megnyeri mindkét félidőt? - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '2,57', 'Leeds': '35,00'}
#
# Nyer legalább egy félidőt? - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,13', 'Leeds': '4,35'}
#
# 0-ra nyeri - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,95', 'Leeds': '16,50'}
#
# 0-ra nyeri - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,85', 'Leeds': '8,25'}
#
# Az adott időszakasz eredménye (perc): 0:00-79:59 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,33', 'Döntetlen': '4,35', 'Leeds': '7,50'}
#
# Az adott időszakasz eredménye (perc): 0:00-74:59 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,33', 'Döntetlen': '3,95', 'Leeds': '9,25'}
#
# Az adott időszakasz eredménye (perc): 0:00-69:59 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,39', 'Döntetlen': '3,85', 'Leeds': '7,50'}
#
# Az adott időszakasz eredménye (perc): 0:00-59:59 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,46', 'Döntetlen': '3,15', 'Leeds': '8,75'}
#
# Az adott időszakasz eredménye (perc): 0:00-49:59 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,60', 'Döntetlen': '2,85', 'Leeds': '7,25'}
#
# Az adott időszakasz eredménye (perc): 0:00-39:59 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,82', 'Döntetlen': '2,34', 'Leeds': '7,50'}
#
# Az adott időszakasz eredménye (perc): 0:00-29:59 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '2,13', 'Döntetlen': '1,87', 'Leeds': '9,25'}
#
# Az adott időszakasz eredménye (perc): 0:00-19:59 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '2,75', 'Döntetlen': '1,56', 'Leeds': '9,25'}
#
# Az adott időszakasz eredménye (perc): 0:00-14:59 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '3,45', 'Döntetlen': '1,36', 'Leeds': '10,50'}
#
# Az adott időszakasz eredménye (perc): 0:00-9:59 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '4,65', 'Döntetlen': '1,21', 'Leeds': '13,50'}
#
# Az adott időszakasz eredménye (perc): 0:00-4:59 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '8,25', 'Döntetlen': '1,06', 'Leeds': '21,00'}
#
# A(z) 1. gól megszerzésének ideje - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'00:00-14:59': '3,00', 'Nincs': '16,00', '15:00-29:59': '3,70', '30:00-45+': '5,00', '45:00-59:59': '8,75', '60:00-74:59': '13,50', '75:00-90+': '16,00'}
#
# Gólszám 0,5 az adott időszakaszban (perc): 0:00-14:59 - Rendes játékidő
# ligroup (sorok) száma: 2
# alcímek száma: 1
# 3. osztály
# {'0,5': {'Több, mint': '2,70', 'Kevesebb, mint': '1,34'}}
#
# Gólszám 0,5 az adott időszakaszban (perc): 15:00-29:59 - Rendes játékidő
# ligroup (sorok) száma: 2
# alcímek száma: 1
# 3. osztály
# {'0,5': {'Több, mint': '2,53', 'Kevesebb, mint': '1,40'}}
#
# Gólszám 0,5 az adott időszakaszban (perc): 30:00-45+ - Rendes játékidő
# ligroup (sorok) száma: 2
# alcímek száma: 1
# 3. osztály
# {'0,5': {'Több, mint': '1,96', 'Kevesebb, mint': '1,66'}}
#
# Gólszám 1. félidő/Gólszám 2. félidő - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'1. félidő 1-3 és 2. félidő 1-3': '1,80', '1. félidő 1-2 és 2. félidő 1-2': '2,62', '1. félidő 2-3 és 2. félidő 2-3': '5,25'}
#
# Gólszám 1,5 az adott időszakaszban (perc): 0:00-14:59 - Rendes játékidő
# ligroup (sorok) száma: 2
# alcímek száma: 1
# 3. osztály
# {'1,5': {'Több, mint': '11,50', 'Kevesebb, mint': ''}}
#
# Gólszám 1,5 az adott időszakaszban (perc): 15:00-29:59 - Rendes játékidő
# ligroup (sorok) száma: 2
# alcímek száma: 1
# 3. osztály
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 await run_scraper(URL, headless=False, interval_sec=60, iterations=1)
#
# Cell In[8], line 36, in run_scraper(url, headless, interval_sec, iterations, parser_fn, on_result)
#      34 # HTML kiolvasása (ASYNC), majd átadjuk a SZINKRON parsernek
#      35 html = await page.content()
# ---> 36 key, result = parser_fn(html)
#      38 # ha adtál callbacket, itt megkapja az eredményt (SZINKRON)
#      39 if on_result:
#
# Cell In[7], line 94, in parse_html(html, kell)
#      92     for li in ligroup[1:]:
#      93         ossdd = [ods.get_text(strip=True) for ods in li.find_all('li')]
# ---> 94         soradatok[ossdd[0]] = {header_titles[0]:ossdd[1], header_titles[2]:ossdd[2]}
#      96 # nincsen header, csak sok alcím
#      97 else:
#      98     print('4. osztály')
#
# IndexError: list index out of range

# %%
key, m = parse_html(html, kell=kelllista)
# Out:
# 1X2 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,27', 'Döntetlen': '5,75', 'Leeds': '10,00'}
#
# Mindkét csapat szerez gólt - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Igen': '2,01', 'Nem': '1,73'}
#
# Gólszám - Rendes játékidő
# ligroup (sorok) száma: 16
# alcímek száma: 15
# 3. osztály
# Gólszám - Rendes játékidő - tobb kevesebb
# {'0,5': {'Több, mint': '', 'Kevesebb, mint': '14,00'}, '1,5': {'Több, mint': '1,15', 'Kevesebb, mint': '4,75'}, '2': {'Több, mint': '1,23', 'Kevesebb, mint': '3,80'}, '2,25': {'Több, mint': '1,39', 'Kevesebb, mint': '2,80'}, '2,5': {'Több, mint': '1,54', 'Kevesebb, mint': '2,34'}, '2,75': {'Több, mint': '1,67', 'Kevesebb, mint': '2,10'}, '3': {'Több, mint': '1,86', 'Kevesebb, mint': '1,86'}, '3,25': {'Több, mint': '2,11', 'Kevesebb, mint': '1,66'}, '3,5': {'Több, mint': '2,36', 'Kevesebb, mint': '1,53'}, '3,75': {'Több, mint': '2,70', 'Kevesebb, mint': '1,41'}, '4': {'Több, mint': '3,40', 'Kevesebb, mint': '1,27'}, '4,25': {'Több, mint': '3,60', 'Kevesebb, mint': '1,25'}, '4,5': {'Több, mint': '4,05', 'Kevesebb, mint': '1,20'}, '5,5': {'Több, mint': '7,50', 'Kevesebb, mint': '1,06'}, '6,5': {'Több, mint': '14,00', 'Kevesebb, mint': ''}}
#
# Hendikep - Rendes játékidő
# ligroup (sorok) száma: 5
# alcímek száma: 5
# 2. osztály
# egyezik a lingroup és a header szám (kihagyás)!!!!
#
# Döntetlennél a tét visszajár - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,07', 'Leeds': '7,25'}
#
# Ázsiai hendikep - Rendes játékidő
# ligroup (sorok) száma: 23
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'-3,5': '5,25', '+3,5': '1,15', '-3': '4,65', '+3': '1,19', '-2,75': '3,50', '+2,75': '1,30', '-2,5': '2,85', '+2,5': '1,42', '-2,25': '2,57', '+2,25': '1,51', '-2': '60,00', '+2': '1,62', '-1,75': '30,00', '+1,75': '1,85', '-1,5': '23,00', '+1,5': '2,05', '-1,25': '22,00', '+1,25': '2,38', '-1': '22,00', '+1': '3,00', '-0,75': '11,50', '+0,75': '1,03', '-0,5': '8,25', '+0,5': '1,07', '-0,25': '7,50', '+0,25': '1,08', '0': '7,00'}
#
# Gólszám - Rendes játékidő
# ligroup (sorok) száma: 3
# alcímek száma: 3
# 2. osztály
#
# Gólszám - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# Gólszám - Rendes játékidő - paros paratlan
# {'Páratlan': '1,86', 'Páros': '1,85'}

# %%
key, m = parse_html(html, kell=kelllista)
# Out:
# 1X2 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,27', 'Döntetlen': '5,75', 'Leeds': '10,00'}
#
# Mindkét csapat szerez gólt - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Igen': '2,01', 'Nem': '1,73'}
#
# Gólszám - Rendes játékidő
# ligroup (sorok) száma: 16
# alcímek száma: 15
# 3. osztály
# Gólszám - Rendes játékidő - tobb kevesebb
# {'0,5': {'Több, mint': '', 'Kevesebb, mint': '14,00'}, '1,5': {'Több, mint': '1,15', 'Kevesebb, mint': '4,75'}, '2': {'Több, mint': '1,23', 'Kevesebb, mint': '3,80'}, '2,25': {'Több, mint': '1,39', 'Kevesebb, mint': '2,80'}, '2,5': {'Több, mint': '1,54', 'Kevesebb, mint': '2,34'}, '2,75': {'Több, mint': '1,67', 'Kevesebb, mint': '2,10'}, '3': {'Több, mint': '1,86', 'Kevesebb, mint': '1,86'}, '3,25': {'Több, mint': '2,11', 'Kevesebb, mint': '1,66'}, '3,5': {'Több, mint': '2,36', 'Kevesebb, mint': '1,53'}, '3,75': {'Több, mint': '2,70', 'Kevesebb, mint': '1,41'}, '4': {'Több, mint': '3,40', 'Kevesebb, mint': '1,27'}, '4,25': {'Több, mint': '3,60', 'Kevesebb, mint': '1,25'}, '4,5': {'Több, mint': '4,05', 'Kevesebb, mint': '1,20'}, '5,5': {'Több, mint': '7,50', 'Kevesebb, mint': '1,06'}, '6,5': {'Több, mint': '14,00', 'Kevesebb, mint': ''}}
#
# Hendikep - Rendes játékidő
# ligroup (sorok) száma: 5
# alcímek száma: 5
# 2. osztály
# egyezik a lingroup és a header szám (kihagyás)!!!!
#
# Döntetlennél a tét visszajár - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# {'Manchester City': '1,07', 'Leeds': '7,25'}
#
# Ázsiai hendikep - Rendes játékidő
# ligroup (sorok) száma: 23
# alcímek száma: 0
# 3. osztály
# 4. osztály
# Nincsen header %%%%%
# {'-3,5': '5,25', '+3,5': '1,15', '-3': '4,65', '+3': '1,19', '-2,75': '3,50', '+2,75': '1,30', '-2,5': '2,85', '+2,5': '1,42', '-2,25': '2,57', '+2,25': '1,51', '-2': '60,00', '+2': '1,62', '-1,75': '30,00', '+1,75': '1,85', '-1,5': '23,00', '+1,5': '2,05', '-1,25': '22,00', '+1,25': '2,38', '-1': '22,00', '+1': '3,00', '-0,75': '11,50', '+0,75': '1,03', '-0,5': '8,25', '+0,5': '1,07', '-0,25': '7,50', '+0,25': '1,08', '0': '7,00'}
#
# Gólszám - Rendes játékidő
# ligroup (sorok) száma: 3
# alcímek száma: 3
# 2. osztály
#
# Gólszám - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# 1. osztály
# Gólszám - Rendes játékidő - paros paratlan
# {'Páratlan': '1,86', 'Páros': '1,85'}

# %%
def odd_to_float(odd):
    return float(0 if odd == '' else odd.replace(',', '.'))

# %%
adatok = {}
for k, v in m.items():
    market = df.columns[df.loc[df['Unnamed: 0'] == 'tippmix'].iloc[0] == k].tolist()[0]
    print(market)

    oddadatok = {}

    for nev, odd in v.items():
        nev = normalize_text(nev).replace(',', '.')
        
        if type(odd) == dict: 
            
            for alcim, alodd in odd.items():
                alodd = odd_to_float(alodd)
                alcim = normalize_text(alcim).replace(',', '')
                tcim = nev+'_'+alcim
                oddadatok[tcim] = alodd
                print('\t', tcim, '\t', alodd)
        else:
            oddadatok[nev] = odd_to_float(odd)
            print('\t', nev, '\t', odd)
            
    adatok[market] = oddadatok
# Out:
# vegkimenetel
# 	 portugalia 	 1,25
# 	 dontetlen 	 6,50
# 	 magyarorszag 	 12,00
# mindket_csapat_szerez_golt
# 	 igen 	 1,97
# 	 nem 	 1,88
# golszam
# 	 0.5_tobb_mint 	 0.0
# 	 0.5_kevesebb_mint 	 17.5
# 	 1.5_tobb_mint 	 1.14
# 	 1.5_kevesebb_mint 	 5.75
# 	 1.75_tobb_mint 	 1.16
# 	 1.75_kevesebb_mint 	 5.25
# 	 2_tobb_mint 	 1.18
# 	 2_kevesebb_mint 	 4.85
# 	 2.25_tobb_mint 	 1.31
# 	 2.25_kevesebb_mint 	 3.45
# 	 2.5_tobb_mint 	 1.43
# 	 2.5_kevesebb_mint 	 2.8
# 	 2.75_tobb_mint 	 1.52
# 	 2.75_kevesebb_mint 	 2.52
# 	 3_tobb_mint 	 1.65
# 	 3_kevesebb_mint 	 2.24
# 	 3.25_tobb_mint 	 1.87
# 	 3.25_kevesebb_mint 	 1.93
# 	 3.5_tobb_mint 	 2.05
# 	 3.5_kevesebb_mint 	 1.77
# 	 3.75_tobb_mint 	 2.33
# 	 3.75_kevesebb_mint 	 1.61
# 	 4_tobb_mint 	 2.7
# 	 4_kevesebb_mint 	 1.46
# 	 4.25_tobb_mint 	 3.0
# 	 4.25_kevesebb_mint 	 1.38
# 	 4.5_tobb_mint 	 3.25
# 	 4.5_kevesebb_mint 	 1.33
# 	 4.75_tobb_mint 	 3.95
# 	 4.75_kevesebb_mint 	 1.25
# 	 5_tobb_mint 	 5.0
# 	 5_kevesebb_mint 	 1.17
# 	 5.25_tobb_mint 	 5.25
# 	 5.25_kevesebb_mint 	 1.15
# 	 5.5_tobb_mint 	 5.5
# 	 5.5_kevesebb_mint 	 1.14
# 	 6.5_tobb_mint 	 11.0
# 	 6.5_kevesebb_mint 	 1.04
# 	 7.5_tobb_mint 	 22.0
# 	 7.5_kevesebb_mint 	 0.0
# 	 8.5_tobb_mint 	 45.0
# 	 8.5_kevesebb_mint 	 0.0
# dontetlenre_nem_lehet_fogadni
# 	 portugalia 	 1,05
# 	 magyarorszag 	 9,50
# azsiai_hendikep
# 	 -4.5 	 7,50
# 	 +4.5 	 1,08
# 	 -4 	 6,50
# 	 +4 	 1,10
# 	 -3.75 	 5,25
# 	 +3.75 	 1,16
# 	 -3.5 	 4,20
# 	 +3.5 	 1,23
# 	 -3.25 	 3,90
# 	 +3.25 	 1,25
# 	 -3 	 3,50
# 	 +3 	 1,30
# 	 -2.75 	 2,85
# 	 +2.75 	 1,42
# 	 -2.5 	 2,48
# 	 +2.5 	 1,54
# 	 -2.25 	 2,22
# 	 +2.25 	 1,66
# 	 -2 	 80,00
# 	 +2 	 1,83
# 	 -1.75 	 40,00
# 	 +1.75 	 2,05
# 	 -1.5 	 29,00
# 	 +1.5 	 2,30
# 	 -1.25 	 28,00
# 	 +1.25 	 2,70
# 	 -1 	 28,00
# 	 +1 	 3,50
# 	 -0.75 	 14,50
# 	 +0.75 	 1,01
# 	 -0.5 	 10,00
# 	 +0.5 	 1,04
# 	 -0.25 	 9,75
# 	 +0.25 	 1,05
# 	 0 	 9,25
# paros_vagy_paratlan_a_golszam
# 	 paratlan 	 1,85
# 	 paros 	 1,84

# %%
df
# Out:
#   Unnamed: 0           végkimenetel  \
# 0    tippmix  1X2 - Rendes játékidő
# 1     ivibet                    1X2
#
#                     mindkét csapat szerez gólt                     gólszám  \
# 0  Mindkét csapat szerez gólt - Rendes játékidő  Gólszám - Rendes játékidő
# 1                        Mindkét csapat betalál                 Összesítet
#
#                      ázsiai hendikep páros vagy páratlan a gólszám  \
# 0  Ázsiai hendikep - Rendes játékidő     Gólszám - Rendes játékidő
# 1                    ázsiai hendikep               Páros/ páratlan
#
#                      hendikep                   döntetlenre nem lehet fogadni
# 0  Hendikep - Rendes játékidő  Döntetlennél a tét visszajár - Rendes játékidő
# 1                    Hendikep                               xre nincs fogadás

# %% [markdown]
# 1X2 - Rendes játékidő !
# Mindkét csapat szerez gólt - Rendes játékidő !
# Hendikep - Rendes játékidő !
# Döntetlennél a tét visszajár - Rendes játékidő !
# Ázsiai hendikep - Rendes játékidő !
# Gólszám - Rendes játékidő !
# Gólszám - Rendes játékidő
#
# Gólszám - Rendes játékidő

# %%
def egysegesito_tippmix(m, df):
    adatok = {}
    for k, v in m.items():
        market = df.columns[df.loc[df['Unnamed: 0'] == 'tippmix'].iloc[0] == k].tolist()[0]

        oddadatok = {}

        for nev, odd in v.items():
            nev = normalize_text(nev).replace(',', '.')

            if type(odd) == dict:

                for alcim, alodd in odd.items():
                    alodd = odd_to_float(alodd)
                    alcim = normalize_text(alcim).replace(',', '')
                    tcim = nev + '_' + alcim
                    oddadatok[tcim] = alodd
            else:
                oddadatok[nev] = odd_to_float(odd)

        adatok[market] = oddadatok

    return adatok

def get_key(soup):
    hazai = normalize_text(soup.select_one('.MatchDetailsHeader__PartName--Home').get_text())
    venged = normalize_text(soup.select_one('.MatchDetailsHeader__PartName--Away').get_text())
    s = soup.select_one('.MatchTime__InfoPart').get_text()
    datum = dateparser.parse(s, languages=['hu']).strftime("%Y-%m-%d")
    return f'{hazai}-{venged}-{datum}-tippmix'

# %%
soup = None
def parse_html2(html, df, kell=None):
    """
    Szinkron feldolgozás.
    Adatkinyerés
    """
    markets = {}

    soup = BeautifulSoup(html, "html.parser")

    container = soup.select_one(".MarketGroupsItem")

    if container is None:
        # nincs fő konténer -> üres eredmény
        return markets

    if kell:
        kell.append('Gólszám - Rendes játékidő')

    for article in container.select("article"):

        soradatok = {}

        header_el = article.select_one(".Market__CollapseText")
        header_text = header_el.get_text(strip=True) if header_el else ""

        if kell:  # ha van kell lista akkor,
            if header_text not in kell:  # ha nincsen benne a text akkor ki kell hagyni
                continue

        oddsgroup = article.select("ul.Market__OddsGroups")  # li elemek listája ezen az ul tag-en belül

        if len(oddsgroup) == 0:
            continue

        ligroup = oddsgroup[0].find_all('li', recursive=False)

        alcimCount = len(oddsgroup[0].find_all("li", class_="Market__OddsGroupTitle"))

        # ha nincsen alcím és nincsen header
        if len(ligroup) == 1 and alcimCount == 0:

            if header_text == 'Gólszám - Rendes játékidő':
                header_text = header_text + ' - paros paratlan'

            group = ligroup[0]  # egy eleme van akkor a gorup legyen az egyetlen elem

            for alcim in group.find_all("li"):
                oszlop = [i.get_text(strip=True) for i in alcim.find_all('span')]
                if len(oszlop) < 2:
                    continue
                soradatok[oszlop[0]] = oszlop[1]  # oszlop 0 itt lehet névcsere

            print('1 osztály')

        # ha van alcím

        # a header száma egyezik a lingroup számmal
        elif alcimCount == len(ligroup):

            if header_text == 'Gólszám - Rendes játékidő':
                continue

            print('2 osztály')
            print(header_text)
            print()
            
            continue
            # be kéne itt még fejezni ezt a lehetőséget

        
        # egy header van (header van az első helyen)
        elif "Market__HeadersWrapper" in ligroup[0].get("class", []):
            header_titles = [i.get_text(strip=True) for i in ligroup[0].find_all('li')]

            if header_text == 'Gólszám - Rendes játékidő':
                header_text = header_text + ' - tobb kevesebb'

            # ha van header akkor még el kell dönteni, hogy van-e Market__OddsGroupTitle
            if ligroup[1].select_one("li.Market__OddsGroupTitle"):

                for li in ligroup[1:]:
                    ossdd = [ods.get_text(strip=True) for ods in li.find_all('li')]
                    soradatok[ossdd[0]] = {header_titles[0]: ossdd[1], header_titles[2]: ossdd[2]}
            
                print('3 osztály, 1 opció')
            
            # nincsen header, csak sok alcím
            else:
                cimek = [i.get_text(strip=True) for i in ligroup[0].find_all('li')]
                
                print(cimek)
                
                for sor in ligroup[1:]:
                    for i, oszlop in enumerate(sor.find_all('li')):
                        
                        #print(cimek[i])
                        
                        if len(oszlop.find_all('span')) != 2:
                            continue
                            
                        text, odds = [m.get_text(strip=True) for m in oszlop.find_all('span')] # ['-3,5', '5,25']

                        textt = f'{'1' if i == 0 else '2'}_{text}'
                        print(textt, odds)
                        soradatok[textt] = odds

                print('3 osztály, 2 opció')
                
        print(header_text)
        print(soradatok)
        print()
                
        markets[header_text] = soradatok
        
    return markets

# %%
m = parse_html2(html, df=df, kell=kelllista)
# Out:
# 1 osztály
# 1X2 - Rendes játékidő
# {'Manchester City': '1,27', 'Döntetlen': '5,75', 'Leeds': '10,00'}
#
# 1 osztály
# Mindkét csapat szerez gólt - Rendes játékidő
# {'Igen': '2,01', 'Nem': '1,73'}
#
# 3 osztály, 1 opció
# Gólszám - Rendes játékidő - tobb kevesebb
# {'0,5': {'Több, mint': '', 'Kevesebb, mint': '14,00'}, '1,5': {'Több, mint': '1,15', 'Kevesebb, mint': '4,75'}, '2': {'Több, mint': '1,23', 'Kevesebb, mint': '3,80'}, '2,25': {'Több, mint': '1,39', 'Kevesebb, mint': '2,80'}, '2,5': {'Több, mint': '1,54', 'Kevesebb, mint': '2,34'}, '2,75': {'Több, mint': '1,67', 'Kevesebb, mint': '2,10'}, '3': {'Több, mint': '1,86', 'Kevesebb, mint': '1,86'}, '3,25': {'Több, mint': '2,11', 'Kevesebb, mint': '1,66'}, '3,5': {'Több, mint': '2,36', 'Kevesebb, mint': '1,53'}, '3,75': {'Több, mint': '2,70', 'Kevesebb, mint': '1,41'}, '4': {'Több, mint': '3,40', 'Kevesebb, mint': '1,27'}, '4,25': {'Több, mint': '3,60', 'Kevesebb, mint': '1,25'}, '4,5': {'Több, mint': '4,05', 'Kevesebb, mint': '1,20'}, '5,5': {'Több, mint': '7,50', 'Kevesebb, mint': '1,06'}, '6,5': {'Több, mint': '14,00', 'Kevesebb, mint': ''}}
#
# 2 osztály
# Hendikep - Rendes játékidő
#
# 1 osztály
# Döntetlennél a tét visszajár - Rendes játékidő
# {'Manchester City': '1,07', 'Leeds': '7,25'}
#
# ['Manchester City', 'Leeds']
# 1_-3,5 5,25
# 2_+3,5 1,15
# 1_-3 4,65
# 2_+3 1,19
# 1_-2,75 3,50
# 2_+2,75 1,30
# 1_-2,5 2,85
# 2_+2,5 1,42
# 1_-2,25 2,57
# 2_+2,25 1,51
# 1_-2 2,29
# 2_+2 1,62
# 1_-1,75 1,96
# 2_+1,75 1,85
# 1_-1,5 1,77
# 2_+1,5 2,05
# 1_-1,25 1,58
# 2_+1,25 2,38
# 1_-1 1,38
# 2_+1 3,00
# 1_-0,75 1,31
# 2_+0,75 3,40
# 1_-0,5 1,27
# 2_+0,5 3,75
# 1_-0,25 1,17
# 2_+0,25 5,00
# 1_0 1,09
# 2_0 7,00
# 1_+0,25 1,08
# 2_-0,25 7,50
# 1_+0,5 1,07
# 2_-0,5 8,25
# 1_+0,75 1,03
# 2_-0,75 11,50
# 2_-1 22,00
# 2_-1,25 22,00
# 2_-1,5 23,00
# 2_-1,75 30,00
# 2_-2 60,00
# 3 osztály, 2 opció
# Ázsiai hendikep - Rendes játékidő
# {'1_-3,5': '5,25', '2_+3,5': '1,15', '1_-3': '4,65', '2_+3': '1,19', '1_-2,75': '3,50', '2_+2,75': '1,30', '1_-2,5': '2,85', '2_+2,5': '1,42', '1_-2,25': '2,57', '2_+2,25': '1,51', '1_-2': '2,29', '2_+2': '1,62', '1_-1,75': '1,96', '2_+1,75': '1,85', '1_-1,5': '1,77', '2_+1,5': '2,05', '1_-1,25': '1,58', '2_+1,25': '2,38', '1_-1': '1,38', '2_+1': '3,00', '1_-0,75': '1,31', '2_+0,75': '3,40', '1_-0,5': '1,27', '2_+0,5': '3,75', '1_-0,25': '1,17', '2_+0,25': '5,00', '1_0': '1,09', '2_0': '7,00', '1_+0,25': '1,08', '2_-0,25': '7,50', '1_+0,5': '1,07', '2_-0,5': '8,25', '1_+0,75': '1,03', '2_-0,75': '11,50', '2_-1': '22,00', '2_-1,25': '22,00', '2_-1,5': '23,00', '2_-1,75': '30,00', '2_-2': '60,00'}
#
# 1 osztály
# Gólszám - Rendes játékidő - paros paratlan
# {'Páratlan': '1,86', 'Páros': '1,85'}

# %%
m
# Out:
# {'1X2 - Rendes játékidő': {'Manchester City': '1,27',
#   'Döntetlen': '5,75',
#   'Leeds': '10,00'},
#  'Mindkét csapat szerez gólt - Rendes játékidő': {'Igen': '2,01',
#   'Nem': '1,73'},
#  'Gólszám - Rendes játékidő - tobb kevesebb': {'0,5': {'Több, mint': '',
#    'Kevesebb, mint': '14,00'},
#   '1,5': {'Több, mint': '1,15', 'Kevesebb, mint': '4,75'},
#   '2': {'Több, mint': '1,23', 'Kevesebb, mint': '3,80'},
#   '2,25': {'Több, mint': '1,39', 'Kevesebb, mint': '2,80'},
#   '2,5': {'Több, mint': '1,54', 'Kevesebb, mint': '2,34'},
#   '2,75': {'Több, mint': '1,67', 'Kevesebb, mint': '2,10'},
#   '3': {'Több, mint': '1,86', 'Kevesebb, mint': '1,86'},
#   '3,25': {'Több, mint': '2,11', 'Kevesebb, mint': '1,66'},
#   '3,5': {'Több, mint': '2,36', 'Kevesebb, mint': '1,53'},
#   '3,75': {'Több, mint': '2,70', 'Kevesebb, mint': '1,41'},
#   '4': {'Több, mint': '3,40', 'Kevesebb, mint': '1,27'},
#   '4,25': {'Több, mint': '3,60', 'Kevesebb, mint': '1,25'},
#   '4,5': {'Több, mint': '4,05', 'Kevesebb, mint': '1,20'},
#   '5,5': {'Több, mint': '7,50', 'Kevesebb, mint': '1,06'},
#   '6,5': {'Több, mint': '14,00', 'Kevesebb, mint': ''}},
#  'Döntetlennél a tét visszajár - Rendes játékidő': {'Manchester City': '1,07',
#   'Leeds': '7,25'},
#  'Ázsiai hendikep - Rendes játékidő': {'1_-3,5': '5,25',
#   '2_+3,5': '1,15',
#   '1_-3': '4,65',
#   '2_+3': '1,19',
#   '1_-2,75': '3,50',
#   '2_+2,75': '1,30',
#   '1_-2,5': '2,85',
#   '2_+2,5': '1,42',
#   '1_-2,25': '2,57',
#   '2_+2,25': '1,51',
#   '1_-2': '2,29',
#   '2_+2': '1,62',
#   '1_-1,75': '1,96',
#   '2_+1,75': '1,85',
#   '1_-1,5': '1,77',
#   '2_+1,5': '2,05',
#   '1_-1,25': '1,58',
#   '2_+1,25': '2,38',
#   '1_-1': '1,38',
#   '2_+1': '3,00',
#   '1_-0,75': '1,31',
#   '2_+0,75': '3,40',
#   '1_-0,5': '1,27',
#   '2_+0,5': '3,75',
#   '1_-0,25': '1,17',
#   '2_+0,25': '5,00',
#   '1_0': '1,09',
#   '2_0': '7,00',
#   '1_+0,25': '1,08',
#   '2_-0,25': '7,50',
#   '1_+0,5': '1,07',
#   '2_-0,5': '8,25',
#   '1_+0,75': '1,03',
#   '2_-0,75': '11,50',
#   '2_-1': '22,00',
#   '2_-1,25': '22,00',
#   '2_-1,5': '23,00',
#   '2_-1,75': '30,00',
#   '2_-2': '60,00'},
#  'Gólszám - Rendes játékidő - paros paratlan': {'Páratlan': '1,86',
#   'Páros': '1,85'}}

# %%
def get_key(soup):
    hazai = normalize_text(soup.select_one('.MatchDetailsHeader__PartName--Home').get_text()).replace('_', ' ').split()[0]
    venged = normalize_text(soup.select_one('.MatchDetailsHeader__PartName--Away').get_text()).replace('_', ' ').split()[0]
    s = soup.select_one('.MatchTime__InfoPart').get_text()
    datum = dateparser.parse(s, languages=['hu']).strftime("%Y-%m-%d")
    return f'{hazai}-{venged}-{datum}-tippmix'

# %%
get_key(soup)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 get_key(soup)
#
# Cell In[120], line 2, in get_key(soup)
#       1 def get_key(soup):
# ----> 2     hazai = normalize_text(soup.select_one('.MatchDetailsHeader__PartName--Home').get_text()).replace('_', ' ').split()[0]
#       3     venged = normalize_text(soup.select_one('.MatchDetailsHeader__PartName--Away').get_text()).replace('_', ' ').split()[0]
#       4     s = soup.select_one('.MatchTime__InfoPart').get_text()
#
# AttributeError: 'NoneType' object has no attribute 'select_one'
