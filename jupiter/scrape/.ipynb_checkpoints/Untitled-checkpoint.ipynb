# %%
import json
import asyncio
from datetime import datetime
from playwright.async_api import async_playwright
from bs4 import BeautifulSoup

# %%
URL = "https://sports2.tippmixpro.hu/hu/esemenyek/1/labdarugas/anglia/premier-liga/burnley-leeds/282537778038837248/all"

# %%
with open('tipmix.txt', encoding='utf-8') as f:
    kellenek = [line.strip() for line in f]

# %%
def parse_html(html, kell=None):
    """
    Szinkron feldolgozás.
    Adatkinyerés
    """

    if kell is None:
        kell = set()

    markets = {}

    soup = BeautifulSoup(html, "html.parser")

    container = soup.select_one(".MarketGroupsItem")

    if container is None:
        # nincs fő konténer -> üres eredmény
        return markets


    for article in container.select("article"):
        
        soradatok = {}

        header_el = article.select_one(".Market__CollapseText")
        header_text = header_el.get_text(strip=True) if header_el else ""

        #if header_text not in kell:
        #    continue

        oddsgroup = article.select("ul.Market__OddsGroups")  # li elemek listája ezen az ul tag-en belül

        print(header_text)

        if len(oddsgroup) == 0:  
            print('bezárt menü')
            continue

        ligroup = oddsgroup[0].find_all('li', recursive=False)
        print('ligroup (sorok) száma:', len(ligroup))
    
        alcimCount = len(oddsgroup[0].find_all("li", class_="Market__OddsGroupTitle"))
        print('alcímek száma:', alcimCount)

        
        # ha nincsen alcím és nincsen header
        if len(ligroup) == 1 and alcimCount == 0:  
            group = ligroup[0] # egy eleme van akkor a gorup legyen az egyetlen elem

            for alcim in group.find_all("li"):
                oszlop = [i.get_text(strip=True) for i in alcim.find_all('span')]
                soradatok[oszlop[0]] = oszlop[1]     # oszlop 0 itt lehet névcsere
                     
        # ha van alcím

        # egy header van (header van az első helyen)
        elif "Market__HeadersWrapper" in ligroup[0].get("class", []):
            header_titles = [i.get_text(strip=True) for i in ligroup[0].find_all('li')]
            #print('\t\t header:', header_titles)

            # ha van header akkor még el kell dönteni, hogy van-e Market__OddsGroupTitle
            if ligroup[1].select_one("li.Market__OddsGroupTitle"):
                
                for li in ligroup[1:]:
                    ossdd = [ods.get_text(strip=True) for ods in li.find_all('li')]
                    soradatok[ossdd[0]] = {header_titles[0]:ossdd[1], header_titles[2]:ossdd[2]}

            # több header van
            #elif:
            #    print('több header van!!!!')

            # nincsen header, csak sok alcím
            else:
                print('Nincsen header %%%%%')
                for sor in ligroup[1:]:
                    for i, oszlop in enumerate(sor.find_all('li')):
                        if len(oszlop.find_all('span')) != 2:
                            continue

                        text, odds = [m.get_text(strip=True) for m in oszlop.find_all('span')]
                        #print(header_titles[i], text, odds)
                        #print(text, odds)
                        soradatok[text] = odds
                        
        markets[header_text] = soradatok
        print(soradatok)
        print()
        
    return markets

# %%
m = parse_html(html, kell=kellenek)
# Out:
# 1X2 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley': '3,00', 'Döntetlen': '3,35', 'Leeds': '2,48'}
#
# Mindkét csapat szerez gólt - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Igen': '1,85', 'Nem': '1,95'}
#
# 1X2 + Mindkét csapat szerez gólt - Rendes játékidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# Nincsen header %%%%%
# {'Hazai és Igen': '6,00', 'Hazai és Nem': '5,00', 'Döntetlen és Nem': '9,25', 'Döntetlen és Igen': '4,50', 'Vendég és Nem': '3,95', 'Vendég és Igen': '4,85'}
#
# Gólszám - Rendes játékidő
# ligroup (sorok) száma: 19
# alcímek száma: 18
# {'0,5': {'Több, mint': '1,06', 'Kevesebb, mint': '8,50'}, '0,75': {'Több, mint': '1,07', 'Kevesebb, mint': '8,25'}, '1': {'Több, mint': '1,09', 'Kevesebb, mint': '7,25'}, '1,25': {'Több, mint': '1,23', 'Kevesebb, mint': '4,20'}, '1,5': {'Több, mint': '1,36', 'Kevesebb, mint': '3,15'}, '1,75': {'Több, mint': '1,45', 'Kevesebb, mint': '2,75'}, '2': {'Több, mint': '1,58', 'Kevesebb, mint': '2,38'}, '2,25': {'Több, mint': '1,84', 'Kevesebb, mint': '1,97'}, '2,5': {'Több, mint': '2,11', 'Kevesebb, mint': '1,73'}, '2,75': {'Több, mint': '2,43', 'Kevesebb, mint': '1,56'}, '3': {'Több, mint': '3,05', 'Kevesebb, mint': '1,38'}, '3,25': {'Több, mint': '3,40', 'Kevesebb, mint': '1,31'}, '3,5': {'Több, mint': '3,75', 'Kevesebb, mint': '1,27'}, '3,75': {'Több, mint': '4,75', 'Kevesebb, mint': '1,19'}, '4': {'Több, mint': '6,50', 'Kevesebb, mint': '1,11'}, '4,5': {'Több, mint': '7,50', 'Kevesebb, mint': '1,08'}, '5,5': {'Több, mint': '16,50', 'Kevesebb, mint': ''}, '6,5': {'Több, mint': '30,00', 'Kevesebb, mint': ''}}
#
# Burnley gólszám - Rendes játékidő
# ligroup (sorok) száma: 5
# alcímek száma: 4
# {'0,5': {'Több, mint': '1,38', 'Kevesebb, mint': '2,80'}, '1,5': {'Több, mint': '2,75', 'Kevesebb, mint': '1,39'}, '2,5': {'Több, mint': '7,00', 'Kevesebb, mint': '1,07'}, '3,5': {'Több, mint': '20,00', 'Kevesebb, mint': ''}}
#
# Leeds gólszám - Rendes játékidő
# ligroup (sorok) száma: 5
# alcímek száma: 4
# {'0,5': {'Több, mint': '1,33', 'Kevesebb, mint': '3,15'}, '1,5': {'Több, mint': '2,50', 'Kevesebb, mint': '1,48'}, '2,5': {'Több, mint': '5,75', 'Kevesebb, mint': '1,11'}, '3,5': {'Több, mint': '16,00', 'Kevesebb, mint': ''}}
#
# Hendikep - Rendes játékidő
# ligroup (sorok) száma: 5
# alcímek száma: 5
# {}
#
# Kétesély - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley vagy Döntetlen': '1,56', 'Burnley vagy Leeds': '1,35', 'Leeds vagy Döntetlen': '1,38'}
#
# Döntetlennél a tét visszajár - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley': '2,14', 'Leeds': '1,71'}
#
# 1X2 + Gólszám 1,5 - Rendes játékidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# Nincsen header %%%%%
# {'Hazai és Több, mint 1,5': '3,75', 'Hazai és Kevesebb, mint 1,5': '8,00', 'Döntetlen és Több, mint 1,5': '4,70', 'Döntetlen és Kevesebb, mint 1,5': '9,25', 'Vendég és Több, mint 1,5': '3,20', 'Vendég és Kevesebb, mint 1,5': '7,25'}
#
# 1X2 + Gólszám 2,5 - Rendes játékidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# Nincsen header %%%%%
# {'Hazai és Több, mint 2,5': '4,95', 'Hazai és Kevesebb, mint 2,5': '5,25', 'Döntetlen és Több, mint 2,5': '13,50', 'Döntetlen és Kevesebb, mint 2,5': '4,05', 'Vendég és Több, mint 2,5': '4,25', 'Vendég és Kevesebb, mint 2,5': '4,75'}
#
# 1X2 + Gólszám 3,5 - Rendes játékidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# Nincsen header %%%%%
# {'Hazai és Több, mint 3,5': '10,00', 'Hazai és Kevesebb, mint 3,5': '3,45', 'Döntetlen és Több, mint 3,5': '13,50', 'Döntetlen és Kevesebb, mint 3,5': '4,05', 'Vendég és Több, mint 3,5': '8,75', 'Vendég és Kevesebb, mint 3,5': '3,00'}
#
# 1X2 + Gólszám 4,5 - Rendes játékidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# Nincsen header %%%%%
# {'Hazai és Több, mint 4,5': '18,00', 'Hazai és Kevesebb, mint 4,5': '3,05', 'Döntetlen és Több, mint 4,5': '60,00', 'Döntetlen és Kevesebb, mint 4,5': '3,40', 'Vendég és Több, mint 4,5': '15,50', 'Vendég és Kevesebb, mint 4,5': '2,68'}
#
# 1X2 + Gólszám 5,5 - Rendes játékidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# Nincsen header %%%%%
# {'Hazai és Több, mint 5,5': '45,00', 'Hazai és Kevesebb, mint 5,5': '2,80', 'Döntetlen és Több, mint 5,5': '60,00', 'Döntetlen és Kevesebb, mint 5,5': '3,40', 'Vendég és Több, mint 5,5': '35,00', 'Vendég és Kevesebb, mint 5,5': '2,47'}
#
# Mindkét csapat szerez gólt vagy több, mint 2,5 gól lesz - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Igen': '1,60', 'Nem': '2,06'}
#
# Félidő/végeredmény - Rendes játékidő
# ligroup (sorok) száma: 3
# alcímek száma: 0
# {}
#
# Pontos eredmény - Rendes játékidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# Nincsen header %%%%%
# {'1:0': '7,75', '2:0': '13,50', '2:1': '9,75', '3:0': '30,00', '3:1': '23,00', '3:2': '30,00', '4:0': '70,00', '4:1': '60,00', '4:2': '70,00', '4:3': '125,00', '5:0': '125,00', '5:1': '125,00', '5:2': '175,00', '5:3': '200,00', '5:4': '175,00', '6:0': '150,00', '6:1': '150,00', '6:2': '125,00', '6:3': '175,00', '6:4': '175,00', '6:5': '175,00', '7:0': '125,00', '7:1': '125,00', '8:0': '125,00', '9:0': '125,00', '0:0': '8,50', '1:1': '5,75', '2:2': '14,50', '3:3': '50,00', '4:4': '200,00', '5:5': '175,00', '0:1': '6,75', '0:2': '10,50', '1:2': '8,75', '0:3': '22,00', '1:3': '19,50', '2:3': '28,00', '0:4': '50,00', '1:4': '50,00', '2:4': '60,00', '3:4': '100,00', '0:5': '100,00', '1:5': '90,00', '2:5': '125,00', '3:5': '200,00', '4:5': '175,00', '0:6': '175,00', '1:6': '175,00', '2:6': '125,00', '3:6': '175,00', '4:6': '175,00', '5:6': '175,00', '0:7': '125,00', '1:7': '125,00', '0:8': '125,00', '0:9': '125,00', '0:10': '125,00'}
#
# Szerez gólt? - Rendes játékidő
# ligroup (sorok) száma: 3
# alcímek száma: 0
# Nincsen header %%%%%
# {'Jacob Bruun Larsen': '2,95', 'Lyle Foster': '3,45', 'Armando Broja': '3,45', 'Flemming Zian': '3,65', 'Mike Trésor': '3,65', 'Jaidon Anthony': '3,95', 'Marcus Edwards': '3,95', 'Ashley Barnes': '4,35', 'Loum Tchaouna': '5,00', 'Hannibal Mejbri': '6,25', 'Josh Laurent': '7,25', 'Lucas Pires': '7,75', 'Joshua Cullen': '10,00', 'Lesley Ugochukwu': '11,50', 'Oliver Sonne': '11,50', 'Quilindschy Hartman': '11,50', 'Maxime Esteve': '11,50', 'Hjalmar Ekdal': '12,50', 'Connor Roberts': '15,50', 'Bashir Humphreys': '15,50', 'Axel Tuanzebe': '17,00', 'Joe Worrall': '17,50', 'Kyle Walker': '19,00', 'Dominic Calvert-Lewin': '2,65', 'Joël Piroe': '2,85', 'Lukas Nmecha': '3,20', 'Wilfried Gnonto': '3,65', 'Brenden Aaronson': '4,60', 'Anton Stach': '5,50', 'Jack Harrison': '5,50', 'Ao Tanaka': '7,25', 'Pascal Struijk': '8,25', 'Gabriel Gudmundsson': '8,75', 'Sean Longstaff': '8,75', 'Jayden Bogle': '10,00', 'James Justin': '11,00', 'Sebastiaan Bornauw': '11,00', 'Ilia Gruev': '11,00', 'Jaka Bijol': '11,00', 'Ethan Ampadu': '11,50', 'Joe Rodon': '15,50', 'Sam Byram': '15,50'}
#
# Ki szerzi a(z) 1. gólt? - Rendes játékidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# Nincsen header %%%%%
# {'Jacob Bruun Larsen': '7,25', 'Lyle Foster': '8,00', 'Armando Broja': '8,00', 'Flemming Zian': '8,50', 'Mike Trésor': '8,50', 'Jaidon Anthony': '8,75', 'Ashley Barnes': '9,25', 'Marcus Edwards': '9,50', 'Loum Tchaouna': '11,50', 'Hannibal Mejbri': '16,50', 'Josh Laurent': '18,00', 'Lucas Pires': '20,00', 'Joshua Cullen': '25,00', 'Quilindschy Hartman': '29,00', 'Oliver Sonne': '30,00', 'Maxime Esteve': '30,00', 'Lesley Ugochukwu': '30,00', 'Hjalmar Ekdal': '30,00', 'Connor Roberts': '35,00', 'Bashir Humphreys': '35,00', 'Axel Tuanzebe': '40,00', 'Joe Worrall': '40,00', 'Kyle Walker': '45,00', 'Dominic Calvert-Lewin': '5,75', 'Joël Piroe': '6,25', 'Lukas Nmecha': '7,50', 'Wilfried Gnonto': '8,75', 'Brenden Aaronson': '10,00', 'Anton Stach': '14,50', 'Jack Harrison': '14,50', 'Ao Tanaka': '18,00', 'Pascal Struijk': '19,00', 'Sean Longstaff': '21,00', 'Gabriel Gudmundsson': '22,00', 'Jayden Bogle': '24,00', 'James Justin': '26,00', 'Jaka Bijol': '28,00', 'Ilia Gruev': '28,00', 'Sebastiaan Bornauw': '28,00', 'Ethan Ampadu': '29,00', 'Joe Rodon': '35,00', 'Sam Byram': '35,00', 'Nem lesz 1. gól': '8,75'}
#
# Ázsiai hendikep - Rendes játékidő
# ligroup (sorok) száma: 18
# alcímek száma: 0
# Nincsen header %%%%%
# {'-2': '10,50', '+2': '1,04', '-1,75': '6,25', '+1,75': '1,11', '-1,5': '4,70', '+1,5': '1,19', '-1,25': '4,30', '+1,25': '1,22', '-1': '3,80', '+1': '1,26', '-0,75': '2,80', '+0,75': '1,43', '-0,5': '2,35', '+0,5': '1,60', '-0,25': '2,06', '+0,25': '1,76', '0': '1,71'}
#
# 1X2 - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley': '3,55', 'Döntetlen': '2,04', 'Leeds': '2,95'}
#
# 1X2 - 2. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley': '3,15', 'Döntetlen': '2,35', 'Leeds': '2,70'}
#
# Gólszám - 1. félidő
# ligroup (sorok) száma: 10
# alcímek száma: 9
# {'0,5': {'Több, mint': '1,43', 'Kevesebb, mint': '2,67'}, '0,75': {'Több, mint': '1,60', 'Kevesebb, mint': '2,23'}, '1': {'Több, mint': '2,01', 'Kevesebb, mint': '1,73'}, '1,25': {'Több, mint': '2,48', 'Kevesebb, mint': '1,49'}, '1,5': {'Több, mint': '2,95', 'Kevesebb, mint': '1,35'}, '1,75': {'Több, mint': '3,95', 'Kevesebb, mint': '1,22'}, '2': {'Több, mint': '6,50', 'Kevesebb, mint': '1,08'}, '2,5': {'Több, mint': '7,75', 'Kevesebb, mint': '1,05'}, '3,5': {'Több, mint': '22,00', 'Kevesebb, mint': ''}}
#
# Gólszám - 2. félidő
# ligroup (sorok) száma: 5
# alcímek száma: 4
# {'0,5': {'Több, mint': '1,28', 'Kevesebb, mint': '3,40'}, '1,5': {'Több, mint': '2,26', 'Kevesebb, mint': '1,58'}, '2,5': {'Több, mint': '5,00', 'Kevesebb, mint': '1,14'}, '3,5': {'Több, mint': '12,50', 'Kevesebb, mint': ''}}
#
# Ázsiai hendikep - 1. félidő
# ligroup (sorok) száma: 18
# alcímek száma: 0
# Nincsen header %%%%%
# {'-2': '35,00', '-1,75': '15,00', '-1,5': '9,50', '-1,25': '9,00', '+1,25': '1,03', '-1': '8,00', '+1': '1,05', '-0,75': '4,15', '+0,75': '1,20', '-0,5': '2,90', '+0,5': '1,37', '-0,25': '2,36', '+0,25': '1,54', '0': '1,74', '+1,5': '1,03'}
#
# Ázsiai hendikep - 2. félidő
# ligroup (sorok) száma: 2
# alcímek száma: 0
# Nincsen header %%%%%
# {'+1,5': '1,06', '-1,5': '7,25'}
#
# Mindkét csapat szerez gólt - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Igen': '4,70', 'Nem': '1,16'}
#
# Mindkét csapat szerez gólt - 2. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Igen': '3,50', 'Nem': '1,26'}
#
# Mindkét csapat szerez gólt + Gólszám - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Nem és Kevesebb, mint 2,5': '2,21', 'Igen és Több, mint 2,5': '2,40', 'Igen és Kevesebb, mint 2,5': '6,25', 'Nem és Több, mint 2,5': '10,00'}
#
# Mindkét csapat szerez gólt + Gólszám - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Nem és Kevesebb, mint 2,5': '1,18', 'Igen és Kevesebb, mint 2,5': '8,25', 'Igen és Több, mint 2,5': '11,00', 'Nem és Több, mint 2,5': '30,00'}
#
# Mindkét csapat szerez gólt + Gólszám - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Nem és Kevesebb, mint 3,5': '1,15', 'Igen és Kevesebb, mint 3,5': '5,50', 'Igen és Több, mint 3,5': '30,00', 'Nem és Több, mint 3,5': '125,00'}
#
# Kétesély + Mindkét csapat szerez gólt - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley vagy Leeds és Nem': '2,18', 'Leeds vagy Döntetlen és Igen': '2,63', 'Burnley vagy Döntetlen és Igen': '2,75', 'Leeds vagy Döntelen és Nem': '2,85', 'Burnley vagy Leeds és Igen': '2,95', 'Burnley vagy Döntelen és Nem': '3,20'}
#
# Kétesély + Mindkét csapat szerez gólt - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Leeds vagy Döntelen és Nem': '1,56', 'Burnley vagy Döntelen és Nem': '1,65', 'Burnley vagy Leeds és Nem': '1,90', 'Leeds vagy Döntetlen és Igen': '6,00', 'Burnley vagy Döntetlen és Igen': '6,25', 'Burnley vagy Leeds és Igen': '12,00'}
#
# Mindkét félidőben lesz gól - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Igen': '1,84', 'Nem': '1,84'}
#
# 1. gól „X” perc előtt lesz? - Rendes játékidő
# ligroup (sorok) száma: 9
# alcímek száma: 8
# {'10': {'Igen': '4,25', 'Nem': '1,14'}, '20': {'Igen': '2,45', 'Nem': '1,42'}, '30': {'Igen': '1,83', 'Nem': '1,77'}, '40': {'Igen': '1,53', 'Nem': '2,19'}, '50': {'Igen': '1,31', 'Nem': '2,85'}, '60': {'Igen': '1,19', 'Nem': '3,65'}, '70': {'Igen': '1,11', 'Nem': '4,65'}, '80': {'Igen': '1,06', 'Nem': '5,75'}}
#
# Félidő gólszám kombináció - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'1. fi - Kevesebb, mint 1,5 és 2. fi - Kevesebb, mint 1,5': '2,13', '1. fi - Több, mint 1,5 és 2. fi - Több, mint 1,5': '6,75'}
#
# Burnley „X” perc előtt szerzi a(z) 1. gólját - Rendes játékidő
# ligroup (sorok) száma: 9
# alcímek száma: 8
# {'10': {'Igen': '7,50', 'Nem': '1,02'}, '20': {'Igen': '4,30', 'Nem': '1,14'}, '30': {'Igen': '3,10', 'Nem': '1,26'}, '40': {'Igen': '2,51', 'Nem': '1,40'}, '50': {'Igen': '2,05', 'Nem': '1,61'}, '60': {'Igen': '1,79', 'Nem': '1,81'}, '70': {'Igen': '1,61', 'Nem': '2,05'}, '80': {'Igen': '1,48', 'Nem': '2,30'}}
#
# Leeds „X” perc előtt szerzi a(z) 1. gólját - Rendes játékidő
# ligroup (sorok) száma: 9
# alcímek száma: 8
# {'10': {'Igen': '7,00', 'Nem': '1,03'}, '20': {'Igen': '4,00', 'Nem': '1,16'}, '30': {'Igen': '2,85', 'Nem': '1,31'}, '40': {'Igen': '2,33', 'Nem': '1,47'}, '50': {'Igen': '1,91', 'Nem': '1,70'}, '60': {'Igen': '1,68', 'Nem': '1,94'}, '70': {'Igen': '1,52', 'Nem': '2,21'}, '80': {'Igen': '1,40', 'Nem': '2,51'}}
#
# Melyik csapat szerzi a(z) 1. gólt? - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley': '2,08', 'Nincs': '8,25', 'Leeds': '1,89'}
#
# Melyik félidőben lesz több gól? - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'1. félidő': '3,05', '2. félidő': '2,08', 'Döntetlen': '3,25'}
#
# Gólszám - Rendes játékidő
# ligroup (sorok) száma: 3
# alcímek száma: 3
# {}
#
# Gólszám - 1. félidő
# ligroup (sorok) száma: 3
# alcímek száma: 3
# {}
#
# Gólszám - 2. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 1
# {}
#
# Nem kap gólt - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley': '3,20', 'Leeds': '2,90'}
#
# Nem kap gólt - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley': '1,64', 'Leeds': '1,56'}
#
# Hátrányból nyer - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley': '12,00', 'Leeds': '10,50'}
#
# Pontos eredmény - 1. félidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# Nincsen header %%%%%
# {'1:0': '4,70', '2:0': '16,50', '2:1': '25,00', '3:0': '60,00', '3:1': '70,00', '3:2': '175,00', '0:0': '2,64', '1:1': '7,50', '2:2': '50,00', '0:1': '4,25', '0:2': '12,50', '1:2': '22,00', '0:3': '50,00', '1:3': '70,00', '2:3': '125,00', '0:4': '100,00'}
#
# Pontos eredmény - 2. félidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# Nincsen header %%%%%
# {'1:0': '5,00', '2:0': '13,50', '2:1': '19,00', '0:0': '3,55', '1:1': '6,50', '2:2': '35,00', '0:1': '4,65', '0:2': '12,00', '1:2': '17,00'}
#
# Kétesély - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley vagy Döntetlen': '1,28', 'Burnley vagy Leeds': '1,61', 'Leeds vagy Döntetlen': '1,21'}
#
# Kétesély - 2. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley vagy Döntetlen': '1,35', 'Burnley vagy Leeds': '1,46', 'Leeds vagy Döntetlen': '1,25'}
#
# Kétesély + Gólszám 1,5 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley vagy Leeds és Több, mint 1,5': '1,81', 'Leeds vagy Döntetlen és Több, mint 1,5': '2,00', 'Burnley vagy Döntetlen és Több, mint 1,5': '2,20', 'Burnley vagy Leeds és Kevesebb, mint 1,5': '4,15', 'Leeds vagy Döntetlen és Kevesebb, mint 1,5': '4,40', 'Burnley vagy Döntetlen és Kevesebb, mint 1,5': '4,65'}
#
# Kétesély + Gólszám 2,5 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Leeds vagy Döntetlen és Kevesebb, mint 2,5': '2,30', 'Burnley vagy Leeds és Több, mint 2,5': '2,40', 'Burnley vagy Döntetlen és Kevesebb, mint 2,5': '2,43', 'Burnley vagy Leeds és Kevesebb, mint 2,5': '2,65', 'Leeds vagy Döntetlen és Több, mint 2,5': '3,40', 'Burnley vagy Döntetlen és Több, mint 2,5': '3,85'}
#
# Kétesély + Gólszám 3,5 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley vagy Leeds és Kevesebb, mint 3,5': '1,68', 'Leeds vagy Döntetlen és Kevesebb, mint 3,5': '1,81', 'Burnley vagy Döntetlen és Kevesebb, mint 3,5': '1,95', 'Burnley vagy Leeds és Több, mint 3,5': '5,00', 'Leeds vagy Döntetlen és Több, mint 3,5': '5,75', 'Burnley vagy Döntetlen és Több, mint 3,5': '6,25'}
#
# Kétesély + Gólszám 4,5 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley vagy Leeds és Kevesebb, mint 4,5': '1,48', 'Leeds vagy Döntetlen és Kevesebb, mint 4,5': '1,55', 'Burnley vagy Döntetlen és Kevesebb, mint 4,5': '1,67', 'Burnley vagy Leeds és Több, mint 4,5': '9,00', 'Leeds vagy Döntetlen és Több, mint 4,5': '13,50', 'Burnley vagy Döntetlen és Több, mint 4,5': '15,50'}
#
# Kétesély + Gólszám 1,5 - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Leeds vagy Döntetlen és Kevesebb, mint 1,5': '1,75', 'Burnley vagy Döntetlen és Kevesebb, mint 1,5': '1,81', 'Burnley vagy Leeds és Kevesebb, mint 1,5': '2,48', 'Leeds vagy Döntetlen és Több, mint 1,5': '4,25', 'Burnley vagy Döntetlen és Több, mint 1,5': '4,60', 'Burnley vagy Leeds és Több, mint 1,5': '4,70'}
#
# Kétesély + Gólszám 2,5 - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Leeds vagy Döntetlen és Kevesebb, mint 2,5': '1,38', 'Burnley vagy Döntetlen és Kevesebb, mint 2,5': '1,43', 'Burnley vagy Leeds és Kevesebb, mint 2,5': '1,98', 'Burnley vagy Leeds és Több, mint 2,5': '9,50', 'Leeds vagy Döntetlen és Több, mint 2,5': '14,50', 'Burnley vagy Döntetlen és Több, mint 2,5': '16,50'}
#
# Kétesély + Gólszám 3,5 - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Leeds vagy Döntetlen és Kevesebb, mint 3,5': '1,31', 'Burnley vagy Döntetlen és Kevesebb, mint 3,5': '1,37', 'Burnley vagy Leeds és Kevesebb, mint 3,5': '1,73', 'Burnley vagy Leeds és Több, mint 3,5': '40,00', 'Leeds vagy Döntetlen és Több, mint 3,5': '40,00', 'Burnley vagy Döntetlen és Több, mint 3,5': '40,00'}
#
# Kétesély + Gólszám 4,5 - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Leeds vagy Döntetlen és Kevesebb, mint 4,5': '1,28', 'Burnley vagy Döntetlen és Kevesebb, mint 4,5': '1,35', 'Burnley vagy Leeds és Kevesebb, mint 4,5': '1,70', 'Burnley vagy Leeds és Több, mint 4,5': '100,00', 'Leeds vagy Döntetlen és Több, mint 4,5': '125,00', 'Burnley vagy Döntetlen és Több, mint 4,5': '150,00'}
#
# Döntetlennél a tét visszajár - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley': '1,99', 'Leeds': '1,65'}
#
# Döntetlennél a tét visszajár - 2. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley': '1,95', 'Leeds': '1,67'}
#
# Félidő eredménye vagy végeredmény - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley': '2,20', 'Döntetlen': '1,68', 'Leeds': '1,96'}
#
# Félidő/végeredmény + Gólszám 1,5 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Leeds / Leeds és Több, mint 1,5': '5,00', 'Burnley / Burnley és Több, mint 1,5': '6,00', 'Döntetlen / Döntetlen és Kevesebb, mint 1,5': '9,50', 'Döntetlen / Döntetlen és Több, mint 1,5': '9,75', 'Döntetlen / Leeds és Több, mint 1,5': '10,00', 'Döntetlen / Burnley és Több, mint 1,5': '11,50', 'Döntetlen / Leeds és Kevesebb, mint 1,5': '12,50', 'Döntetlen / Burnley és Kevesebb, mint 1,5': '14,00', 'Leeds / Leeds és Kevesebb, mint 1,5': '15,50', 'Leeds / Döntetlen és Több, mint 1,5': '15,50', 'Burnley / Döntetlen és Több, mint 1,5': '15,50', 'Burnley / Burnley és Kevesebb, mint 1,5': '17,00', 'Burnley / Leeds és Több, mint 1,5': '30,00', 'Leeds / Burnley és Több, mint 1,5': '35,00'}
#
# Félidő/végeredmény + Gólszám 2,5 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Döntetlen / Döntetlen és Kevesebb, mint 2,5': '5,75', 'Leeds / Leeds és Több, mint 2,5': '6,75', 'Burnley / Burnley és Több, mint 2,5': '8,00', 'Leeds / Leeds és Kevesebb, mint 2,5': '8,50', 'Burnley / Burnley és Kevesebb, mint 2,5': '9,75', 'Döntetlen / Leeds és Kevesebb, mint 2,5': '9,75', 'Döntetlen / Burnley és Kevesebb, mint 2,5': '10,50', 'Döntetlen / Leeds és Több, mint 2,5': '13,50', 'Döntetlen / Burnley és Több, mint 2,5': '15,00', 'Burnley / Döntetlen és Kevesebb, mint 2,5': '22,00', 'Leeds / Döntetlen és Kevesebb, mint 2,5': '22,00', 'Burnley / Leeds és Több, mint 2,5': '30,00', 'Döntetlen / Döntetlen és Több, mint 2,5': '30,00', 'Burnley / Döntetlen és Több, mint 2,5': '35,00', 'Leeds / Döntetlen és Több, mint 2,5': '35,00', 'Leeds / Burnley és Több, mint 2,5': '35,00'}
#
# Félidő/végeredmény + Gólszám 3,5 - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Leeds / Leeds és Kevesebb, mint 3,5': '5,25', 'Döntetlen / Döntetlen és Kevesebb, mint 3,5': '5,75', 'Burnley / Burnley és Kevesebb, mint 3,5': '6,25', 'Döntetlen / Leeds és Kevesebb, mint 3,5': '7,00', 'Döntetlen / Burnley és Kevesebb, mint 3,5': '7,75', 'Leeds / Leeds és Több, mint 3,5': '12,50', 'Burnley / Burnley és Több, mint 3,5': '15,50', 'Burnley / Döntetlen és Kevesebb, mint 3,5': '22,00', 'Leeds / Döntetlen és Kevesebb, mint 3,5': '22,00', 'Döntetlen / Burnley és Több, mint 3,5': '30,00', 'Döntetlen / Leeds és Több, mint 3,5': '30,00', 'Döntetlen / Döntetlen és Több, mint 3,5': '30,00', 'Leeds / Döntetlen és Több, mint 3,5': '35,00', 'Burnley / Döntetlen és Több, mint 3,5': '35,00', 'Burnley / Leeds és Kevesebb, mint 3,5': '50,00', 'Leeds / Burnley és Kevesebb, mint 3,5': '50,00', 'Leeds / Burnley és Több, mint 3,5': '60,00', 'Burnley / Leeds és Több, mint 3,5': '60,00'}
#
# Hendikep - 1. félidő
# ligroup (sorok) száma: 3
# alcímek száma: 3
# {}
#
# Melyik csapat szerzi az utolsó gólt? - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley': '2,08', 'Nincs': '8,25', 'Leeds': '1,88'}
#
# 1X2 + Gólszám 1,5 - 1. félidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# Nincsen header %%%%%
# {'Hazai és Több, mint 1,5': '9,25', 'Hazai és Kevesebb, mint 1,5': '4,85', 'Döntetlen és Több, mint 1,5': '7,50', 'Döntetlen és Kevesebb, mint 1,5': '2,61', 'Vendég és Több, mint 1,5': '7,75', 'Vendég és Kevesebb, mint 1,5': '4,40'}
#
# 1X2 + Gólszám 2,5 - 1. félidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# Nincsen header %%%%%
# {'Hazai és Több, mint 2,5': '19,00', 'Hazai és Kevesebb, mint 2,5': '4,10', 'Döntetlen és Több, mint 2,5': '70,00', 'Döntetlen és Kevesebb, mint 2,5': '2,15', 'Vendég és Több, mint 2,5': '16,50', 'Vendég és Kevesebb, mint 2,5': '3,60'}
#
# 1X2 + Gólszám 3,5 - 1. félidő
# ligroup (sorok) száma: 4
# alcímek száma: 0
# Nincsen header %%%%%
# {'Hazai és Több, mint 3,5': '70,00', 'Hazai és Kevesebb, mint 3,5': '3,55', 'Döntetlen és Több, mint 3,5': '70,00', 'Döntetlen és Kevesebb, mint 3,5': '2,13', 'Vendég és Több, mint 3,5': '60,00', 'Vendég és Kevesebb, mint 3,5': '3,15'}
#
# Gólszám - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Páratlan': '1,89', 'Páros': '1,87'}
#
# Gólszám - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Páratlan': '2,08', 'Páros': '1,68'}
#
# Gólszám - 2. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Páratlan': '1,99', 'Páros': '1,74'}
#
# Burnley kapott gól nélkül játssza le - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley: Igen': '3,00', 'Burnley: Nem': '1,28'}
#
# Leeds kapott gól nélkül játssza le - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Leeds: Igen': '2,70', 'Leeds: Nem': '1,34'}
#
# Leeds kapott gól nélkül játssza le - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Leeds: Igen': '1,52', 'Leeds: Nem': '2,21'}
#
# Burnley kapott gól nélkül játssza le - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley: Igen': '1,60', 'Burnley: Nem': '2,06'}
#
# Burnley gólszám - 1. félidő
# ligroup (sorok) száma: 4
# alcímek száma: 3
# {'0,5': {'Több, mint': '2,30', 'Kevesebb, mint': '1,55'}, '1,5': {'Több, mint': '7,75', 'Kevesebb, mint': '1,05'}, '2,5': {'Több, mint': '28,00', 'Kevesebb, mint': ''}}
#
# Leeds gólszám - 1. félidő
# ligroup (sorok) száma: 4
# alcímek száma: 3
# {'0,5': {'Több, mint': '2,08', 'Kevesebb, mint': '1,67'}, '1,5': {'Több, mint': '6,50', 'Kevesebb, mint': '1,08'}, '2,5': {'Több, mint': '22,00', 'Kevesebb, mint': ''}}
#
# Burnley gólszám - 2. félidő
# ligroup (sorok) száma: 3
# alcímek száma: 2
# {'0,5': {'Több, mint': '1,92', 'Kevesebb, mint': '1,79'}, '1,5': {'Több, mint': '5,50', 'Kevesebb, mint': '1,11'}}
#
# Leeds gólszám - 2. félidő
# ligroup (sorok) száma: 3
# alcímek száma: 2
# {'0,5': {'Több, mint': '1,78', 'Kevesebb, mint': '1,93'}, '1,5': {'Több, mint': '4,85', 'Kevesebb, mint': '1,15'}}
#
# Burnley kaput eltaláló gólszerzési kísérletek száma - Rendes játékidő
# ligroup (sorok) száma: 4
# alcímek száma: 3
# {'2,5': {'Több, mint': '1,28', 'Kevesebb, mint': '3,05'}, '3,5': {'Több, mint': '1,72', 'Kevesebb, mint': '1,89'}, '4,5': {'Több, mint': '2,50', 'Kevesebb, mint': '1,40'}}
#
# Leeds kaput eltaláló gólszerzési kísérletek száma - Rendes játékidő
# ligroup (sorok) száma: 3
# alcímek száma: 2
# {'3,5': {'Több, mint': '1,62', 'Kevesebb, mint': '2,02'}, '4,5': {'Több, mint': '2,35', 'Kevesebb, mint': '1,46'}}
#
# Burnley szerez gólt? - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley: Igen': '1,34', 'Burnley: Nem': '2,70'}
#
# Leeds szerez gólt? - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Leeds: Igen': '1,28', 'Leeds: Nem': '3,00'}
#
# Burnley szerez gólt? - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley: Igen': '2,21', 'Burnley: Nem': '1,52'}
#
# Leeds szerez gólt? - 1. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Leeds: Igen': '2,06', 'Leeds: Nem': '1,60'}
#
# Burnley szerez gólt? - 2. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley: Igen': '1,86', 'Burnley: Nem': '1,75'}
#
# Leeds szerez gólt? - 2. félidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Leeds: Igen': '1,75', 'Leeds: Nem': '1,86'}
#
# Leeds mindkét félidőben szerez gólt? - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Leeds: Igen': '3,70', 'Leeds: Nem': '1,22'}
#
# Burnley mindkét félidőben szerez gólt? - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# {'Burnley: Igen': '4,35', 'Burnley: Nem': '1,16'}
#
# Burnley nyeri mindkét félidőt - Rendes játékidő
# ligroup (sorok) száma: 1
# alcímek száma: 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[216], line 1
# ----> 1 m = parse_html(html, kell=kellenek)
#
# Cell In[215], line 52, in parse_html(html, kell)
#      50     for alcim in group.find_all("li"):
#      51         oszlop = [i.get_text(strip=True) for i in alcim.find_all('span')]
# ---> 52         soradatok[oszlop[0]] = oszlop[1]     # oszlop 0 itt lehet névcsere
#      54 # ha van alcím
#      55
#      56 # egy header van (header van az első helyen)
#      57 elif "Market__HeadersWrapper" in ligroup[0].get("class", []):
#
# IndexError: list index out of range

# %%
m
# Out:
# {'1X2 - Rendes játékidő': {'Burnley': '3,00',
#   'Döntetlen': '3,35',
#   'Leeds': '2,48'},
#  'Mindkét csapat szerez gólt - Rendes játékidő': {'Igen': '1,85',
#   'Nem': '1,95'},
#  'Gólszám - Rendes játékidő': {'Páratlan': '1,89', 'Páros': '1,87'},
#  'Hendikep - Rendes játékidő': {},
#  'Mindkét csapat szerez gólt vagy több, mint 2,5 gól lesz - Rendes játékidő': {'Igen': '1,60',
#   'Nem': '2,06'},
#  'Ázsiai hendikep - Rendes játékidő': {'-2': '10,50',
#   '+2': '1,04',
#   '-1,75': '6,25',
#   '+1,75': '1,11',
#   '-1,5': '4,70',
#   '+1,5': '1,19',
#   '-1,25': '4,30',
#   '+1,25': '1,22',
#   '-1': '3,80',
#   '+1': '1,26',
#   '-0,75': '2,80',
#   '+0,75': '1,43',
#   '-0,5': '2,35',
#   '+0,5': '1,60',
#   '-0,25': '2,06',
#   '+0,25': '1,76',
#   '0': '1,71'},
#  '1X2 - 1. félidő': {'Burnley': '3,55', 'Döntetlen': '2,04', 'Leeds': '2,95'},
#  '1X2 - 2. félidő': {'Burnley': '3,15', 'Döntetlen': '2,35', 'Leeds': '2,70'},
#  'Gólszám - 1. félidő': {'Páratlan': '2,08', 'Páros': '1,68'},
#  'Gólszám - 2. félidő': {'Páratlan': '1,99', 'Páros': '1,74'},
#  'Ázsiai hendikep - 1. félidő': {'-2': '35,00',
#   '-1,75': '15,00',
#   '-1,5': '9,50',
#   '-1,25': '9,00',
#   '+1,25': '1,03',
#   '-1': '8,00',
#   '+1': '1,05',
#   '-0,75': '4,15',
#   '+0,75': '1,20',
#   '-0,5': '2,90',
#   '+0,5': '1,37',
#   '-0,25': '2,36',
#   '+0,25': '1,54',
#   '0': '1,74',
#   '+1,5': '1,03'},
#  'Ázsiai hendikep - 2. félidő': {'+1,5': '1,06', '-1,5': '7,25'},
#  'Mindkét csapat szerez gólt - 1. félidő': {'Igen': '4,70', 'Nem': '1,16'},
#  'Mindkét csapat szerez gólt - 2. félidő': {'Igen': '3,50', 'Nem': '1,26'},
#  'Mindkét félidőben lesz gól - Rendes játékidő': {'Igen': '1,84',
#   'Nem': '1,84'},
#  '1. gól „X” perc előtt lesz? - Rendes játékidő': {'10': {'Igen': '4,25',
#    'Nem': '1,14'},
#   '20': {'Igen': '2,45', 'Nem': '1,42'},
#   '30': {'Igen': '1,83', 'Nem': '1,77'},
#   '40': {'Igen': '1,53', 'Nem': '2,19'},
#   '50': {'Igen': '1,31', 'Nem': '2,85'},
#   '60': {'Igen': '1,19', 'Nem': '3,65'},
#   '70': {'Igen': '1,11', 'Nem': '4,65'},
#   '80': {'Igen': '1,06', 'Nem': '5,75'}},
#  'Melyik csapat szerzi a(z) 1. gólt? - Rendes játékidő': {'Burnley': '2,08',
#   'Nincs': '8,25',
#   'Leeds': '1,89'}}

# %%
html = ''
# ------------- ASYNC LOOP -------------
async def run_scraper(url, headless=True, interval_sec=60, iterations=None, parser_fn=parse_html, on_result=None):
    """
    - Megnyitja a böngészőt és az oldalt.
    - Ciklusban (percenként) lekéri az oldal tartalmát.
    - A HTML-t átadja egy SZINKRON parser_fn-nek.
    - Ha adsz on_result callbacket (szinkron), annak átadja az eredményt.
    - iterations: ha None -> végtelen ciklus, ha szám -> ennyiszer fut.
    """
    global html
    
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=headless)
        context = await browser.new_context()
        page = await context.new_page()

        try:
            # első betöltés
            await page.goto(url, timeout=45000)
            await page.wait_for_selector(".MarketGroupsItem", timeout=15000)


            count = 0
            while True:
                # frissítés (reload), vagy újra goto – ahogy jobban esik
                try:
                    await page.reload(timeout=45000)
                    await page.wait_for_selector(".MarketGroupsItem", timeout=15000)
                    
                except Exception:
                    # ha reload nem ok, próbálkozhatsz goto-val
                    await page.goto(url, wait_until="domcontentloaded", timeout=45000)

                # HTML kiolvasása (ASYNC), majd átadjuk a SZINKRON parsernek
                html = await page.content()
                result = parser_fn(html)

                # ha adtál callbacket, itt megkapja az eredményt (SZINKRON)
                if on_result:
                    on_result(result)
                else:
                    # default: csak kiírjuk (váz)
                    print(result)

                count += 1
                if iterations is not None and count >= iterations:
                    break

                await asyncio.sleep(interval_sec)

        finally:
            await context.close()
            await browser.close()

# %%
await run_scraper(URL, headless=False, interval_sec=60, iterations=1)
# Out:
# {}
