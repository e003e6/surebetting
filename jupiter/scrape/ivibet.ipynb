# %%
import pandas as pd
import re
import unicodedata

# %%
df = pd.read_excel("../../Book1.xlsx")
kelllista = df[df['Unnamed: 0'] == 'ivibet'].values[0][1:].tolist()

# %%
kelllista
# Out:
# ['1X2',
#  'Mindkét csapat betalál',
#  'Összesítet',
#  'ázsiai hendikep',
#  'Páros/ páratlan',
#  'Hendikep',
#  'xre nincs fogadás']

# %%
# az excel apaján visszaadja, hogy az ivibetes címsorhoz milyen standardizált név tartozik
df.columns[df.loc[df['Unnamed: 0'] == 'ivibet'].iloc[0] == 'Mindkét csapat betalál'].tolist()[0]
# Out:
# 'mindket_csapat_szerez_golt '

# %%
df
# Out:
#   Unnamed: 0           vegkimenetel  \
# 0    tippmix  1X2 - Rendes játékidő
# 1     ivibet                    1X2
#
#                     mindket_csapat_szerez_golt   \
# 0  Mindkét csapat szerez gólt - Rendes játékidő
# 1                        Mindkét csapat betalál
#
#                                      golszam  \
# 0  Gólszám - Rendes játékidő - tobb kevesebb
# 1                                 Összesítet
#
#                      azsiai_hendikep  \
# 0  Ázsiai hendikep - Rendes játékidő
# 1                    ázsiai hendikep
#
#                 paros_vagy_paratlan_a_golszam                    hendikep  \
# 0  Gólszám - Rendes játékidő - paros paratlan  Hendikep - Rendes játékidő
# 1                             Páros/ páratlan                    Hendikep
#
#                     dontetlenre_nem_lehet_fogadni
# 0  Döntetlennél a tét visszajár - Rendes játékidő
# 1                               xre nincs fogadás

# %%
def normalize_text(s):
    s = s.lower()
    s = unicodedata.normalize('NFD', s)
    s = ''.join(c for c in s if unicodedata.category(c) != 'Mn')
    s = s.replace(' ', '_')
    return s

# %%
data = [{'market': '1X2', 'outcomes': [{'name': 'Portugália', 'odd': '1.24'}, {'name': 'döntetlen', 'odd': '6.6'}, {'name': 'Magyarország', 'odd': '12'}]}, {'market': 'Dupla esély', 'outcomes': [{'name': 'Portugália vagy döntetlen', 'odd': '1.06'}, {'name': 'Portugália vagy Magyarország', 'odd': '1.12'}, {'name': 'döntetlen vagy Magyarország', 'odd': '3.8'}]}, {'market': 'Döntetlenre nincs fogadás', 'outcomes': [{'name': 'Portugália', 'odd': '1.07'}, {'name': 'Magyarország', 'odd': '8.8'}]}, {'market': 'Mindkét csapat betalál', 'outcomes': [{'name': 'igen', 'odd': '1.94'}, {'name': 'nem', 'odd': '1.87'}]}, {'market': 'Összesített', 'outcomes': [{'name': '0.5 felett', 'odd': '1.02'}, {'name': '0.5 alatt', 'odd': '17'}, {'name': '1.5 felett', 'odd': '1.14'}, {'name': '1.5 alatt', 'odd': '6.2'}, {'name': '2 felett', 'odd': '1.18'}, {'name': '2 alatt', 'odd': '5.2'}, {'name': '2.5 felett', 'odd': '1.44'}, {'name': '2.5 alatt', 'odd': '2.9'}, {'name': '3 felett', 'odd': '1.65'}, {'name': '3 alatt', 'odd': '2.31'}, {'name': '3.5 felett', 'odd': '2.08'}, {'name': '3.5 alatt', 'odd': '1.79'}, {'name': '4 felett', 'odd': '2.8'}, {'name': '4 alatt', 'odd': '1.46'}, {'name': '4.5 felett', 'odd': '3.4'}, {'name': '4.5 
name': 'Magyarország (+0.25)', 'odd': '5.8'}]}, {'market': 'Hendikep 0:1', 'outcomes': [{'name': 'Portugália (0:1)', 'odd': '1.61'}, {'name': 'döntetlen(0:1)', 'odd': '4.4'}, {'name': 'Magyarország (0:1)', 'odd': '4.3'}]}, {'market': 'Hendikep 0:2', 'outcomes': [{'name': 'Portugália (0:2)', 'odd': '2.5'}, {'name': 'döntetlen(0:2)', 'odd': '4.2'}, {'name': 'Magyarország (0:2)', 'odd': '2.26'}]}, {'market': 'Hendikep 0:3', 'outcomes': [{'name': 'Portugália (0:3)', 'odd': '4.4'}, {'name': 'döntetlen(0:3)', 'odd': '5.2'}, {'name': 'Magyarország (0:3)', 'odd': '1.51'}]}, {'market': 'Hendikep 0:4', 'outcomes': [{'name': 'Portugália (0:4)', 'odd': '8.8'}, {'name': 'döntetlen(0:4)', 'odd': '7.6'}, {'name': 'Magyarország (0:4)', 'odd': '1.2'}]}, {'market': 'Hendikep 0:5', 'outcomes': [{'name': 'Portugália (0:5)', 'odd': '17'}, {'name': 'döntetlen(0:5)', 'odd': '12'}, {'name': 'Magyarország (0:5)', 'odd': '1.07'}]}, {'market': 'Hendikep 0:6', 'outcomes': [{'name': 'Portugália (0:6)', 'odd': '29'}, {'name': 'döntetlen(0:6)', 'odd': '17'}, {'name': 'Magyarország (0:6)', 'odd': '1.02'}]}, {'market': 'Hendikep 0:7', 'outcomes': [{'name': 'Portugália (0:7)', 'odd': '35'}, {'name': 'döntetlen(0:7)', 'odd': '18'}]}, {'market': 'Hendikep 1:0', 'outcomes': [{'name': 'Portugália (1:0)', 'odd': '1.05'}, {'name': 'döntetlen(1:0)', 'odd': '11'}, {'name': 'Magyarország (1:0)', 'odd': '30'}]}, {'market': 'Páros/ páratlan', 'outcomes': [{'name': 'páratlan', 'odd': '1.9'}, {'name': 'páros', 'odd': '1.88'}]}, {'market': 'Félidő/játékidő', 'outcomes': [{'name': 'Magyarország/döntetlen', 'odd': '26'}, {'name': 'Portugália/Magyarország', 'odd': '100'}, {'name': 'döntetlen/Magyarország', 'odd': '23'}, {'name': 'Magyarország/Magyarország', 'odd': '19'}, {'name': 'Portugália/Portugália', 'odd': '1.52'}, {'name': 'döntetlen/Portugália', 'odd': '4'}, {'name': 'Magyarország/Portugália', 'odd': '21'}, {'name': 'Portugália/döntetlen', 'odd': '22'}, {'name': 'döntetlen/döntetlen', 'odd': '9.2'}]}, {'market': 'Pontos végeredmény', 'outcomes': [{'name': 'other', 'odd': '11'}, {'name': '1:0', 'odd': '9'}, {'name': '2:0', 'odd': '6.6'}, {'name': '2:1', 'odd': '8.8'}, {'name': '3:0', 'odd': '7.2'}, {'name': '3:1', 'odd': '9.6'}, {'name': '3:2', 'odd': '25'}, {'name': '4:0', 'odd': '10'}, {'name': '4:1', 'odd': '14'}, {'name': '4:2', 'odd': '35'}, {'name': '5:0', 'odd': '18'}, {'name': '5:1', 'odd': '25'}, {'name': '6:0', 'odd': '40'}, {'name': '0:0', 'odd': '22'}, {'name': '1:1', 'odd': '12'}, {'name': '2:2', 'odd': '23'}, {'name': '3:3', 'odd': '100'}, {'name': '0:1', 'odd': '30'}, {'name': '0:2', 'odd': '90'}, {'name': '1:2', 'odd': '30'}, {'name': '0:3', 'odd': '101'}, {'name': '1:3', 'odd': '101'}, {'name': '2:3', 'odd': '90'}, {'name': '0:4', 'odd': '101'}, {'name': '1:4', 'odd': '101'}, {'name': '2:4', 'odd': '101'}, {'name': '0:5', 'odd': '101'}, {'name': '1:5', 'odd': '101'}, {'name': '0:6', 'odd': '101'}]}, {'market': 'Győzelem nagysága', 'outcomes': [{'name': 'draw', 'odd': '6.2'}, {'name': 'Portugália by 3+', 'odd': '2.4'}, {'name': 'Portugália by 2', 'odd': '4'}, {'name': 'Portugália by 1', 'odd': '4.3'}, {'name': 'Magyarország by 1', 'odd': '15'}, {'name': 'Magyarország by 2', 'odd': '50'}, {'name': 'Magyarország by 3+', 'odd': '101'}]}, {'market': 'Portugália páros/ páratlan', 'outcomes': [{'name': 'páratlan', 'odd': '1.88'}, {'name': 'páros', 'odd': '1.86'}]}, {'market': 'Magyarország páros/ páratlan', 'outcomes': [{'name': 'páratlan', 'odd': '2.37'}, {'name': 'páros', 'odd': '1.54'}]}]

# %%
adatok = {}
for m in data:
    
    if m['market'] not in kelllista:
        continue

    stndmarket = df.columns[df.loc[df['Unnamed: 0'] == 'ivibet'].iloc[0] == m['market']].tolist()[0]
    print(stndmarket)

    oddsok = {}
    for o in m['outcomes']:
        
        if m['market'] in ['Hendikep', 'ázsiai hendikep']:
            name = re.search(r'\(([^)]+)\)', o['name']).group(1)
        else:
            name = o['name']

        name = normalize_text(name)
        oddsok[name] = float(o['odd'])

        print('\t', name, '\t', float(o['odd']))
    adatok[stndmarket] = oddsok
# Out:
# vegkimenetel
# 	 portugalia 	 1.24
# 	 dontetlen 	 6.6
# 	 magyarorszag 	 12.0
# mindket_csapat_szerez_golt
# 	 igen 	 1.94
# 	 nem 	 1.87
# hendikep
# 	 -3.5 	 4.5
# 	 +3.5 	 1.22
# 	 -3 	 3.8
# 	 +3 	 1.29
# 	 -2.5 	 2.55
# 	 +2.5 	 1.54
# 	 -2 	 2.03
# 	 +2 	 1.83
# 	 -1.5 	 1.65
# 	 +1.5 	 2.31
# 	 -1 	 1.32
# 	 +1 	 3.5
# 	 -0.5 	 1.24
# 	 +0.5 	 4.3
# azsiai_hendikep
# 	 -3.75 	 5.6
# 	 +3.75 	 1.16
# 	 -3.25 	 4.2
# 	 +3.25 	 1.25
# 	 -2.75 	 3.0
# 	 +2.75 	 1.41
# 	 -2.25 	 2.29
# 	 +2.25 	 1.66
# 	 -1.75 	 1.8
# 	 +1.75 	 2.07
# 	 -1.25 	 1.49
# 	 +1.25 	 2.7
# 	 -0.75 	 1.27
# 	 +0.75 	 3.9
# 	 -0.25 	 1.15
# 	 +0.25 	 5.8
# paros_vagy_paratlan_a_golszam
# 	 paratlan 	 1.9
# 	 paros 	 1.88

# %%
adatok
# Out:
# {'vegkimenetel': {'portugalia': 1.24, 'dontetlen': 6.6, 'magyarorszag': 12.0},
#  'mindket_csapat_szerez_golt ': {'igen': 1.94, 'nem': 1.87},
#  'hendikep': {'-3.5': 4.5,
#   '+3.5': 1.22,
#   '-3': 3.8,
#   '+3': 1.29,
#   '-2.5': 2.55,
#   '+2.5': 1.54,
#   '-2': 2.03,
#   '+2': 1.83,
#   '-1.5': 1.65,
#   '+1.5': 2.31,
#   '-1': 1.32,
#   '+1': 3.5,
#   '-0.5': 1.24,
#   '+0.5': 4.3},
#  'azsiai_hendikep': {'-3.75': 5.6,
#   '+3.75': 1.16,
#   '-3.25': 4.2,
#   '+3.25': 1.25,
#   '-2.75': 3.0,
#   '+2.75': 1.41,
#   '-2.25': 2.29,
#   '+2.25': 1.66,
#   '-1.75': 1.8,
#   '+1.75': 2.07,
#   '-1.25': 1.49,
#   '+1.25': 2.7,
#   '-0.75': 1.27,
#   '+0.75': 3.9,
#   '-0.25': 1.15,
#   '+0.25': 5.8},
#  'paros_vagy_paratlan_a_golszam': {'paratlan': 1.9, 'paros': 1.88}}

# %%
def normalize_text(s):
    s = s.lower()
    s = unicodedata.normalize('NFD', s)
    s = ''.join(c for c in s if unicodedata.category(c) != 'Mn')
    s = s.replace(' ', '_')
    return s

# %%
def egysegesito_ivibet(data, df, kelllista):
    adatok = {}
    cimek = None
    
    for m in data:

        if m['market'] not in kelllista:
            continue

        if m['market'] == '1X2':
            cimek = {'1':m['outcomes'][0]['name'], 'x':m['outcomes'][1]['name'], '2':m['outcomes'][2]['name']}
            print(cimek)

        stndmarket = df.columns[df.loc[df['Unnamed: 0'] == 'ivibet'].iloc[0] == m['market']].tolist()[0]

        oddsok = {}
        for o in m['outcomes']:

            if m['market'] in ['Hendikep', 'ázsiai hendikep']:
                #name = re.search(r'\(([^)]+)\)', o['name']).group(1)
                name = o['name']
                print(name)
                name = next(k for k,v in cimek.items() if v in o['name']) + "_" + o['name'].split("(")[1].rstrip(")")
                print(name)
                print()
            else:
                name = o['name']

            name = normalize_text(name)
            oddsok[name] = float(o['odd'])

        adatok[stndmarket] = oddsok

    return adatok

# %%
data = [{'market': '1X2', 'outcomes': [{'name': 'Manchester City FC', 'odd': '1.25'}, {'name': 'döntetlen', 'odd': '5.8'}, {'name': 'Leeds United', 'odd': '10'}]}, {'market': 'Dupla esély', 'outcomes': [{'name': 'Manchester City FC vagy döntetlen', 'odd': '1.06'}, {'name': 'Manchester City FC vagy Leeds United', 'odd': '1.12'}, {'name': 'döntetlen vagy Leeds United', 'odd': '3.15'}]}, {'market': 'Döntetlenre nincs fogadás', 'outcomes': [{'name': 'Manchester City FC', 'odd': '1.07'}, {'name': 'Leeds United', 'odd': '7.2'}]}, {'market': 'Mindkét csapat betalál', 'outcomes': [{'name': 'igen', 'odd': '2.07'}, {'name': 'nem', 'odd': '1.76'}]}, {'market': 'Összesített', 'outcomes': [{'name': '0.5 felett', 'odd': '1.02'}, {'name': '0.5 alatt', 'odd': '12'}, {'name': '1 felett', 'odd': '1.03'}, {'name': '1 alatt', 'odd': '11'}, {'name': '1.5 felett', 'odd': '1.17'}, {'name': '1.5 alatt', 'odd': '4.8'}, {'name': '2 felett', 
'name': 'Leeds United (+2.25)', 'odd': '1.5'}, {'name': 'Manchester City FC (-1.75)', 'odd': '1.94'}, {'name': 'Leeds United (+1.75)', 'odd': '1.84'}, {'name': 'Manchester City FC (-1.25)', 'odd': '1.56'}, {'name': 'Leeds United (+1.25)', 'odd': '2.38'}, {'name': 'Manchester City FC (-0.75)', 'odd': '1.31'}, {'name': 'Leeds United (+0.75)', 'odd': '3.35'}, {'name': 'Manchester City FC (-0.25)', 'odd': '1.17'}, {'name': 'Leeds United (+0.25)', 'odd': '4.9'}]}, {'market': 'Hendikep 0:1', 'outcomes': [{'name': 'Manchester City FC (0:1)', 'odd': '1.73'}, {'name': 'döntetlen(0:1)', 'odd': '4'}, {'name': 'Leeds United (0:1)', 'odd': '3.8'}]}, {'market': 'Hendikep 0:2', 'outcomes': [{'name': 'Manchester City FC (0:2)', 'odd': '2.85'}, {'name': 'döntetlen(0:2)', 'odd': '4.1'}, {'name': 'Leeds United (0:2)', 'odd': '2.03'}]}, {'market': 'Hendikep 0:3', 'outcomes': [{'name': 'Manchester City FC (0:3)', 'odd': '5.4'}, {'name': 'döntetlen(0:3)', 'odd': '5.4'}, {'name': 'Leeds United (0:3)', 'odd': '1.4'}]}, {'market': 'Hendikep 0:4', 'outcomes': [{'name': 'Manchester City FC (0:4)', 'odd': '11'}, {'name': 'döntetlen(0:4)', 'odd': '8.2'}, {'name': 'Leeds United (0:4)', 'odd': '1.14'}]}, {'market': 'Hendikep 0:5', 'outcomes': [{'name': 'Manchester City FC (0:5)', 'odd': '21'}, {'name': 'döntetlen(0:5)', 'odd': '13'}, {'name': 'Leeds United (0:5)', 'odd': '1.04'}]}, {'market': 'Hendikep 0:6', 'outcomes': [{'name': 'Manchester City FC (0:6)', 'odd': '30'}, {'name': 'döntetlen(0:6)', 'odd': '15'}]}, {'market': 'Hendikep 1:0', 'outcomes': [{'name': 'Manchester City FC (1:0)', 'odd': '1.05'}, {'name': 'döntetlen(1:0)', 'odd': '9.6'}, {'name': 'Leeds United (1:0)', 'odd': '27'}]}, {'market': 'Hendikep 2:0', 'outcomes': [{'name': 'döntetlen(2:0)', 'odd': '13'}, {'name': 'Leeds United (2:0)', 'odd': '50'}]}, {'market': 'Páros/ páratlan', 'outcomes': [{'name': 'páratlan', 'odd': '1.89'}, {'name': 'páros', 'odd': '1.88'}]}, {'market': 'Félidő/játékidő', 'outcomes': [{'name': 'Manchester City FC/Manchester City FC', 'odd': '1.6'}, {'name': 'döntetlen/Manchester City FC', 'odd': '3.9'}, {'name': 'Leeds United/Manchester City FC', 'odd': '23'}, {'name': 'Manchester City FC/döntetlen', 'odd': '22'}, {'name': 'döntetlen/döntetlen', 'odd': '8'}, {'name': 'Leeds United/döntetlen', 'odd': '25'}, {'name': 'Manchester City FC/Leeds United', 'odd': '100'}, {'name': 'döntetlen/Leeds United', 'odd': '20'}, {'name': 'Leeds United/Leeds United', 'odd': '18'}]}, {'market': 'Pontos végeredmény', 'outcomes': [{'name': '1:0', 'odd': '7.2'}, {'name': '2:0', 'odd': '5.8'}, {'name': '2:1', 'odd': '8.4'}, {'name': '3:0', 'odd': '7'}, {'name': '3:1', 'odd': '10'}, {'name': '3:2', 'odd': '28'}, {'name': '4:0', 'odd': '11'}, {'name': '4:1', 'odd': '16'}, {'name': '4:2', 'odd': '45'}, {'name': '5:0', 'odd': '22'}, {'name': '5:1', 'odd': '30'}, {'name': '6:0', 'odd': '50'}, {'name': '0:0', 'odd': '17'}, {'name': '1:1', 'odd': '10'}, {'name': '2:2', 'odd': '24'}, {'name': '3:3', 'odd': '101'}, {'name': '0:1', 'odd': '25'}, {'name': '0:2', 'odd': '70'}, {'name': '1:2', 'odd': '29'}, {'name': '0:3', 'odd': '101'}, {'name': '1:3', 'odd': '101'}, {'name': '2:3', 'odd': '101'}, {'name': '0:4', 'odd': '101'}, {'name': '1:4', 'odd': '101'}, {'name': '2:4', 'odd': '101'}, {'name': '0:5', 'odd': '101'}, {'name': '1:5', 'odd': '101'}, {'name': '0:6', 'odd': '101'}, {'name': 'other', 'odd': '17'}]}, {'market': 'Győzelem nagysága', 'outcomes': [{'name': 'draw', 'odd': '5.6'}, {'name': 'Manchester City FC by 3+', 'odd': '2.75'}, {'name': 'Manchester City FC by 2', 'odd': '3.95'}, {'name': 'Manchester City FC by 1', 'odd': '3.9'}, {'name': 'Leeds United by 1', 'odd': '14'}, {'name': 'Leeds United by 2', 'odd': '50'}, {'name': 'Leeds United by 3+', 'odd': '101'}]}, {'market': 'Manchester City FC páros/ páratlan', 'outcomes': [{'name': 'páratlan', 'odd': '1.89'}, {'name': 'páros', 'odd': '1.85'}]}, {'market': 'Leeds United páros/ páratlan', 'outcomes': [{'name': 'páratlan', 'odd': '2.44'}, {'name': 'páros', 'odd': '1.51'}]}]

# %%
egysegesito_ivibet(data, df, kelllista)
# Out:
# {'1': 'Manchester City FC', 'x': 'döntetlen', '2': 'Leeds United'}
# Manchester City FC (-3.5)
# 1_-3.5
#
# Leeds United (+3.5)
# 2_+3.5
#
# Manchester City FC (-3)
# 1_-3
#
# Leeds United (+3)
# 2_+3
#
# Manchester City FC (-2.5)
# 1_-2.5
#
# Leeds United (+2.5)
# 2_+2.5
#
# Manchester City FC (-2)
# 1_-2
#
# Leeds United (+2)
# 2_+2
#
# Manchester City FC (-1.5)
# 1_-1.5
#
# Leeds United (+1.5)
# 2_+1.5
#
# Manchester City FC (-1)
# 1_-1
#
# Leeds United (+1)
# 2_+1
#
# Manchester City FC (-0.5)
# 1_-0.5
#
# Leeds United (+0.5)
# 2_+0.5
#
# Manchester City FC (-3.75)
# 1_-3.75
#
# Leeds United (+3.75)
# 2_+3.75
#
# Manchester City FC (-3.25)
# 1_-3.25
#
# Leeds United (+3.25)
# 2_+3.25
#
# Manchester City FC (-2.75)
# 1_-2.75
#
# Leeds United (+2.75)
# 2_+2.75
#
# Manchester City FC (-2.25)
# 1_-2.25
#
# Leeds United (+2.25)
# 2_+2.25
#
# Manchester City FC (-1.75)
# 1_-1.75
#
# Leeds United (+1.75)
# 2_+1.75
#
# Manchester City FC (-1.25)
# 1_-1.25
#
# Leeds United (+1.25)
# ...
